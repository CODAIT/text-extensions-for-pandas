# %% [markdown]
# # CoNLL_View_Doc.ipynb
#
# Notebook for viewing individual documents from the CoNLL corpus, for use
# alongside the other CoNLL related notebooks in this directory.

# %%
# The Jupyter kernel for this notebook usually starts up inside the notebooks
# directory, but the text_extensions_for_pandas package code is in the parent
# directory. Add that parent directory to the front of the Python include path.
import sys
if (sys.path[0] != ".."):
    sys.path[0] = ".."
    
# Libraries
import numpy as np
import pandas as pd

# And of course we need the text_extensions_for_pandas library itself.
import text_extensions_for_pandas as tp

# Common code shared across notebooks comes from util.py
import util

# %%
# The raw dataset in its original tokenization
raw_data = {
    "validation": tp.conll_2003_to_dataframes("../conll_03/eng.testa"),
    "test": tp.conll_2003_to_dataframes("../conll_03/eng.testb"),
    "train": tp.conll_2003_to_dataframes("../conll_03/eng.train"),
}

# %%
# Convert IOB2-tagged tokens to spans
all_spans = {
    k: [tp.iob_to_spans(df) for df in v] for k, v in raw_data.items()
}

# %%
fold = "test"
doc_offset = 189
doc_df = all_spans[fold][doc_offset]
doc_df[0:60]
# Out:
#                                            token_span ent_type
# 0                                   [11, 16): 'Burma'      LOC
# 1                                 [19, 26): 'Suu Kyi'      PER
# 2                         [59, 74): 'Deborah Charles'      PER
# 3                                 [75, 82): 'RANGOON'      LOC
# 4                                   [94, 99): 'Burma'      LOC
# 5                      [119, 135): 'Aung San Suu Kyi'      PER
# 6                               [476, 483): 'Suu Kyi'      PER
# 7                               [506, 513): 'Rangoon'      LOC
# 8                               [520, 527): 'Suu Kyi'      PER
# 9                               [772, 779): 'Suu Kyi'      PER
# 10        [782, 811): 'National League for Democracy'      ORG
# 11                                  [813, 816): 'NLD'      ORG
# 12                              [905, 912): 'Burmese'     MISC
# 13                            [1044, 1051): 'Suu Kyi'      PER
# 14                          [1064, 1073): 'Win Htein'      PER
# 15                            [1271, 1278): 'Suu Kyi'      PER
# 16                                [1339, 1342): 'NLD'      ORG
# 17                            [1562, 1569): 'Suu Kyi'      PER
# 18                              [1614, 1619): 'Burma'      LOC
# 19                                [1764, 1767): 'NLD'      ORG
# 20                                [1798, 1801): 'NLD'      ORG
# 21  [1859, 1898): 'State Law and Order Restoration...      ORG
# 22                              [1900, 1905): 'SLORC'      ORG
# 23                            [2260, 2267): 'Suu Kyi'      PER
# 24                            [2591, 2598): 'Rangoon'      LOC
# 25                      [2601, 2614): 'Insein Prison'      LOC
# 26                            [2904, 2911): 'Suu Kyi'      PER
# 27                           [2918, 2926): 'Hla Than'      PER
# 28                                [2968, 2971): 'NLD'      ORG
# 29                             [3009, 3015): 'Insein'      LOC
# 30        [3063, 3090): 'James Leander (Leo) Nichols'      PER
# 31                            [3110, 3117): 'Suu Kyi'      PER
# 32                             [3122, 3128): 'Danish'     MISC
# 33                             [3182, 3188): 'Insein'      LOC
# 34                            [3190, 3197): 'Suu Kyi'      PER
# 35                                [3364, 3367): 'NLD'      ORG
# 36                              [3419, 3424): 'Burma'      LOC
# 37                              [3539, 3544): 'Burma'      LOC

# %%
doc_df["token_span"].values
# Out:
# <TokenSpanArray>
# [                                      [11, 16): 'Burma',
#                                      [19, 26): 'Suu Kyi',
#                              [59, 74): 'Deborah Charles',
#                                      [75, 82): 'RANGOON',
#                                        [94, 99): 'Burma',
#                           [119, 135): 'Aung San Suu Kyi',
#                                    [476, 483): 'Suu Kyi',
#                                    [506, 513): 'Rangoon',
#                                    [520, 527): 'Suu Kyi',
#                                    [772, 779): 'Suu Kyi',
#              [782, 811): 'National League for Democracy',
#                                        [813, 816): 'NLD',
#                                    [905, 912): 'Burmese',
#                                  [1044, 1051): 'Suu Kyi',
#                                [1064, 1073): 'Win Htein',
#                                  [1271, 1278): 'Suu Kyi',
#                                      [1339, 1342): 'NLD',
#                                  [1562, 1569): 'Suu Kyi',
#                                    [1614, 1619): 'Burma',
#                                      [1764, 1767): 'NLD',
#                                      [1798, 1801): 'NLD',
#  [1859, 1898): 'State Law and Order Restoration Council',
#                                    [1900, 1905): 'SLORC',
#                                  [2260, 2267): 'Suu Kyi',
#                                  [2591, 2598): 'Rangoon',
#                            [2601, 2614): 'Insein Prison',
#                                  [2904, 2911): 'Suu Kyi',
#                                 [2918, 2926): 'Hla Than',
#                                      [2968, 2971): 'NLD',
#                                   [3009, 3015): 'Insein',
#              [3063, 3090): 'James Leander (Leo) Nichols',
#                                  [3110, 3117): 'Suu Kyi',
#                                   [3122, 3128): 'Danish',
#                                   [3182, 3188): 'Insein',
#                                  [3190, 3197): 'Suu Kyi',
#                                      [3364, 3367): 'NLD',
#                                    [3419, 3424): 'Burma',
#                                    [3539, 3544): 'Burma']
# Length: 38, dtype: TokenSpanType
