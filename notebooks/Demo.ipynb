# %% [markdown]
# <h1>Text Extensions for Pandas</h1>
# <h2>Interactive Dataframe Widget</h2>
# The interactive dataframe widget is an application within the IBM CODAIT team's open source Python library: Text Extension for Pandas. The widget aims to provide data scientists with a meaningful, visual way to interpret NLP (Natural Language Processing) data.

# %% [markdown]
# This demo will walk you though an example session of using the widget and related visualizers provided in the ```jupyter``` sub-module of Text Extensions for Pandas.

# %%
import os
import regex
import sys
import numpy as np
import pandas as pd

# And of course we need the text_extensions_for_pandas library itself.
try:
    import text_extensions_for_pandas as tp
except ModuleNotFoundError as e:
    # If we're running from within the project source tree and the parent Python
    # environment doesn't have the text_extensions_for_pandas package, use the
    # version in the local source tree.
    if not os.getcwd().endswith("notebooks"):
        raise e
    if ".." not in sys.path:
        sys.path.insert(0, "..")
    import text_extensions_for_pandas as tp

# %% [markdown]
# This demo will make use of the CoNLL-2003 dataset, a dataset concerning named entity recognition. For our purposes, we are interested in the categorical entity classifications of ```locations (LOC)```, ```persons (PER)```, ```organizations (ORG)``` and ```miscellaneous (MISC)```.
#
# We will use Text Extensions for Pandas to download and parse the CoNLL dataset into dataframes for us to work with.

# %%
# Download and cache the data set.
# NOTE: This data set is licensed for research use only. Be sure to adhere
#  to the terms of the license when using this data set!
data_set_info = tp.io.conll.maybe_download_conll_data("outputs")
data_set_info
# Out:
# {'train': 'outputs/eng.train',
#  'dev': 'outputs/eng.testa',
#  'test': 'outputs/eng.testb'}

# %%
gold_standard = tp.io.conll.conll_2003_to_dataframes(
    data_set_info["test"], ["pos", "phrase", "ent"], [False, True, True])
gold_standard = [
    df.drop(columns=["pos", "phrase_iob", "phrase_type"])
    for df in gold_standard
]

# %% [markdown]
# Once we have our dataset downloaded and parsed, we can prepare our dataframe for visualization.

# %%
df_doc = gold_standard[0][:30]
df_doc
# Out:
#                         span ent_iob ent_type  \
# 0      [0, 10): '-DOCSTART-'       O     None
# 1         [11, 17): 'SOCCER'       O     None
# 2              [17, 18): '-'       O     None
# 3          [19, 24): 'JAPAN'       B      LOC
# 4            [25, 28): 'GET'       O     None
# 5          [29, 34): 'LUCKY'       O     None
# 6            [35, 38): 'WIN'       O     None
# 7              [38, 39): ','       O     None
# 8          [40, 45): 'CHINA'       B      PER
# 9             [46, 48): 'IN'       O     None
# 10      [49, 57): 'SURPRISE'       O     None
# 11        [58, 64): 'DEFEAT'       O     None
# 12             [64, 65): '.'       O     None
# 13         [66, 71): 'Nadim'       B      PER
# 14         [72, 77): 'Ladki'       I      PER
# 15        [78, 84): 'AL-AIN'       B      LOC
# 16             [84, 85): ','       O     None
# 17        [86, 92): 'United'       B      LOC
# 18          [93, 97): 'Arab'       I      LOC
# 19     [98, 106): 'Emirates'       I      LOC
# 20  [107, 117): '1996-12-06'       O     None
# 21       [118, 123): 'Japan'       B      LOC
# 22       [124, 129): 'began'       O     None
# 23         [130, 133): 'the'       O     None
# 24     [134, 141): 'defence'       O     None
# 25          [142, 144): 'of'       O     None
# 26       [145, 150): 'their'       O     None
# 27       [151, 156): 'Asian'       B     MISC
# 28         [157, 160): 'Cup'       I     MISC
# 29       [161, 166): 'title'       O     None
#
#                                              sentence  line_num
# 0                               [0, 10): '-DOCSTART-'         0
# 1   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...         2
# 2   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...         3
# 3   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...         4
# 4   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...         5
# 5   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...         6
# 6   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...         7
# 7   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...         8
# 8   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...         9
# 9   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...        10
# 10  [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...        11
# 11  [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...        12
# 12  [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...        13
# 13                            [66, 77): 'Nadim Ladki'        15
# 14                            [66, 77): 'Nadim Ladki'        16
# 15  [78, 117): 'AL-AIN, United Arab Emirates 1996-...        18
# 16  [78, 117): 'AL-AIN, United Arab Emirates 1996-...        19
# 17  [78, 117): 'AL-AIN, United Arab Emirates 1996-...        20
# 18  [78, 117): 'AL-AIN, United Arab Emirates 1996-...        21
# 19  [78, 117): 'AL-AIN, United Arab Emirates 1996-...        22
# 20  [78, 117): 'AL-AIN, United Arab Emirates 1996-...        23
# 21  [118, 244): 'Japan began the defence of their ...        25
# 22  [118, 244): 'Japan began the defence of their ...        26
# 23  [118, 244): 'Japan began the defence of their ...        27
# 24  [118, 244): 'Japan began the defence of their ...        28
# 25  [118, 244): 'Japan began the defence of their ...        29
# 26  [118, 244): 'Japan began the defence of their ...        30
# 27  [118, 244): 'Japan began the defence of their ...        31
# 28  [118, 244): 'Japan began the defence of their ...        32
# 29  [118, 244): 'Japan began the defence of their ...        33

# %% [markdown]
# We don't really want to visualize every column in this dataframe as we're only interested in viewing the entity classifications. The next step is to drop any columns we don't care about.

# %%
doc_df = gold_standard[0][:30].drop(columns=['sentence'])
doc_df
# Out:
#                         span ent_iob ent_type  line_num
# 0      [0, 10): '-DOCSTART-'       O     None         0
# 1         [11, 17): 'SOCCER'       O     None         2
# 2              [17, 18): '-'       O     None         3
# 3          [19, 24): 'JAPAN'       B      LOC         4
# 4            [25, 28): 'GET'       O     None         5
# 5          [29, 34): 'LUCKY'       O     None         6
# 6            [35, 38): 'WIN'       O     None         7
# 7              [38, 39): ','       O     None         8
# 8          [40, 45): 'CHINA'       B      PER         9
# 9             [46, 48): 'IN'       O     None        10
# 10      [49, 57): 'SURPRISE'       O     None        11
# 11        [58, 64): 'DEFEAT'       O     None        12
# 12             [64, 65): '.'       O     None        13
# 13         [66, 71): 'Nadim'       B      PER        15
# 14         [72, 77): 'Ladki'       I      PER        16
# 15        [78, 84): 'AL-AIN'       B      LOC        18
# 16             [84, 85): ','       O     None        19
# 17        [86, 92): 'United'       B      LOC        20
# 18          [93, 97): 'Arab'       I      LOC        21
# 19     [98, 106): 'Emirates'       I      LOC        22
# 20  [107, 117): '1996-12-06'       O     None        23
# 21       [118, 123): 'Japan'       B      LOC        25
# 22       [124, 129): 'began'       O     None        26
# 23         [130, 133): 'the'       O     None        27
# 24     [134, 141): 'defence'       O     None        28
# 25          [142, 144): 'of'       O     None        29
# 26       [145, 150): 'their'       O     None        30
# 27       [151, 156): 'Asian'       B     MISC        31
# 28         [157, 160): 'Cup'       I     MISC        32
# 29       [161, 166): 'title'       O     None        33

# %% [markdown]
# Now that our data is prepared for analysis, we can load it up in our widget.

# %%
#widget = tp.jupyter.render_dataframe(df_doc)
widget = tp.jupyter.render_dataframe(doc_df, interactive_columns=["ent_type"])
widget.display()
# Out:
# Output(_dom_classes=('tep--dfwidget--output',))

# %% [markdown]
# If we want to view this widget interactively, we can pass in the additional parameter ```interactive_columns``` with an array of column names we want to become interactive widgets.
#
# One thing you may notice in the above widgets is that the column ```ent_type``` is editable via a text box. This is fine, but there is a more appropriate way to interact with categorical data.

# %%
categorical = pd.Categorical(doc_df["ent_type"], categories=["PER", "LOC", "ORG", "MISC"])
doc_df["ent_type"] = categorical
doc_df.dtypes
# Out:
# span        SpanDtype
# ent_iob        object
# ent_type     category
# line_num        int64
# dtype: object

# %%
[*doc_df["ent_type"].cat.categories.values, 'nan']
# Out:
# ['PER', 'LOC', 'ORG', 'MISC', 'nan']

# %%
widget = tp.jupyter.render_dataframe(doc_df, interactive_columns=["ent_type"])
display(widget._df["ent_type"].cat.categories)
widget.display()
# Out:
# Index(['PER', 'LOC', 'ORG', 'MISC'], dtype='object')
# Output(_dom_classes=('tep--dfwidget--output',))

# %%
out_df = widget.to_dataframe()
out_df
# Out:
#                         span ent_iob ent_type  line_num
# 0      [0, 10): '-DOCSTART-'       O      NaN         0
# 1         [11, 17): 'SOCCER'       O      NaN         2
# 2              [17, 18): '-'       O      NaN         3
# 3          [19, 24): 'JAPAN'       B      LOC         4
# 4            [25, 28): 'GET'       O      NaN         5
# 5          [29, 34): 'LUCKY'       O      NaN         6
# 6            [35, 38): 'WIN'       O      NaN         7
# 7              [38, 39): ','       O      NaN         8
# 8          [40, 45): 'CHINA'       B      LOC         9
# 9             [46, 48): 'IN'       O      NaN        10
# 10      [49, 57): 'SURPRISE'       O      NaN        11
# 11        [58, 64): 'DEFEAT'       O      NaN        12
# 12             [64, 65): '.'       O      NaN        13
# 13         [66, 71): 'Nadim'       B      PER        15
# 14         [72, 77): 'Ladki'       I      PER        16
# 15        [78, 84): 'AL-AIN'       B      LOC        18
# 16             [84, 85): ','       O      NaN        19
# 17        [86, 92): 'United'       B      LOC        20
# 18          [93, 97): 'Arab'       I      LOC        21
# 19     [98, 106): 'Emirates'       I      LOC        22
# 20  [107, 117): '1996-12-06'       O      NaN        23
# 21       [118, 123): 'Japan'       B      LOC        25
# 22       [124, 129): 'began'       O      NaN        26
# 23         [130, 133): 'the'       O      NaN        27
# 24     [134, 141): 'defence'       O      NaN        28
# 25          [142, 144): 'of'       O      NaN        29
# 26       [145, 150): 'their'       O      NaN        30
# 27       [151, 156): 'Asian'       B     MISC        31
# 28         [157, 160): 'Cup'       I     MISC        32
# 29       [161, 166): 'title'       O      NaN        33
