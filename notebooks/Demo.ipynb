# %% [markdown]
# <h1>Text Extensions for Pandas</h1>
# <h2>Interactive Dataframe Widget</h2>
# The interactive dataframe widget is an application within the IBM CODAIT team's open source Python library: Text Extension for Pandas. The widget aims to provide data scientists with a meaningful, visual way to interpret NLP (Natural Language Processing) data.

# %% [markdown]
# This demo will walk you though an example session of using the widget and related visualizers provided in the ```jupyter``` sub-module of Text Extensions for Pandas.

# %%
import os
import regex
import sys
import numpy as np
import pandas as pd

# And of course we need the text_extensions_for_pandas library itself.
try:
    import text_extensions_for_pandas as tp
except ModuleNotFoundError as e:
    # If we're running from within the project source tree and the parent Python
    # environment doesn't have the text_extensions_for_pandas package, use the
    # version in the local source tree.
    if not os.getcwd().endswith("notebooks"):
        raise e
    if ".." not in sys.path:
        sys.path.insert(0, "..")
    import text_extensions_for_pandas as tp

# %% [markdown]
# This demo will make use of the CoNLL-2003 dataset, a dataset concerning named entity recognition. For our purposes, we are interested in the categorical entity classifications of ```locations (LOC)```, ```persons (PER)```, ```organizations (ORG)``` and ```miscellaneous (MISC)```.
#
# We will use Text Extensions for Pandas to download and parse the CoNLL dataset into dataframes for us to work with.

# %%
# Download and cache the data set.
# NOTE: This data set is licensed for research use only. Be sure to adhere
#  to the terms of the license when using this data set!
data_set_info = tp.io.conll.maybe_download_conll_data("outputs")
data_set_info
# Out:
# {'train': 'outputs/eng.train',
#  'dev': 'outputs/eng.testa',
#  'test': 'outputs/eng.testb'}

# %%
gold_standard = tp.io.conll.conll_2003_to_dataframes(
    data_set_info["test"], ["pos", "phrase", "ent"], [False, True, True])
gold_standard = [
    df.drop(columns=["pos", "phrase_iob", "phrase_type"])
    for df in gold_standard
]

# %% [markdown]
# Once we have our dataset downloaded and parsed, we can prepare our dataframe for visualization.

# %%
tokens = gold_standard[0]
tokens
# Out:
#                       span ent_iob ent_type  \
# 0    [0, 10): '-DOCSTART-'       O     None
# 1       [11, 17): 'SOCCER'       O     None
# 2            [17, 18): '-'       O     None
# 3        [19, 24): 'JAPAN'       B      LOC
# 4          [25, 28): 'GET'       O     None
# ..                     ...     ...      ...
# 415   [2178, 2182): 'each'       O     None
# 416   [2183, 2187): 'from'       O     None
# 417    [2188, 2191): 'one'       O     None
# 418   [2192, 2196): 'game'       O     None
# 419      [2196, 2197): '.'       O     None
#
#                                               sentence  line_num
# 0                                [0, 10): '-DOCSTART-'         0
# 1    [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...         2
# 2    [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...         3
# 3    [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...         4
# 4    [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...         5
# ..                                                 ...       ...
# 415  [2138, 2197): 'All four teams are level with o...       437
# 416  [2138, 2197): 'All four teams are level with o...       438
# 417  [2138, 2197): 'All four teams are level with o...       439
# 418  [2138, 2197): 'All four teams are level with o...       440
# 419  [2138, 2197): 'All four teams are level with o...       441
#
# [420 rows x 5 columns]

# %%
sentences = tokens["sentence"].unique()
sentences
# Out:
# <TokenSpanArray>
# [                                                                          [0, 10): '-DOCSTART-',
#                               [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA IN SURPRISE DEFEAT.',
#                                                                          [66, 77): 'Nadim Ladki',
#                                             [78, 117): 'AL-AIN, United Arab Emirates 1996-12-06',
#        [118, 244): 'Japan began the defence of their Asian Cup title with a lucky 2-1 win [...]',
#       [245, 374): 'But China saw their luck desert them in the second match of the group, [...]',
#      [375, 617): 'China controlled most of the match and saw several chances missed until [...]',
#   [618, 735): 'Oleg Shatskiku made sure of the win in injury time, hitting an unstoppable [...]',
#    [736, 821): 'The former Soviet republic was playing in an Asian Cup finals tie for the [...]',
#   [822, 917): 'Despite winning the Asian Games title two years ago, Uzbekistan are in the [...]',
#    [918, 1078): 'Two goals from defensive errors in the last six minutes allowed Japan to [...]',
#       [1079, 1291): 'Takuya Takagi scored the winner in the 88th minute, rising to head a [...]',
#                       [1292, 1350): 'It was the second costly blunder by Syria in four minutes.',
#   [1351, 1502): 'Defender Hassan Abbas rose to intercept a long ball into the area in the [...]',
#   [1503, 1591): 'Nader Jokhadar had given Syria the lead with a well-struck header in the [...]',
#  [1592, 1701): 'Japan then laid siege to the Syrian penalty area for most of the game but [...]',
#                                   [1702, 1748): 'Bitar pulled off fine saves whenever they did.',
#          [1749, 1820): 'Japan coach Shu Kamo said: ' ' The Syrian own goal proved lucky for us.',
#      [1821, 1925): 'The Syrians scored early and then played defensively and adopted long [...]',
#                                                                                [1926, 1927): ''',
#   [1928, 2049): 'Japan, co-hosts of the World Cup in 2002 and ranked 20th in the world by [...]',
#     [2050, 2137): 'Hosts UAE play Kuwait and South Korea take on Indonesia on Saturday in [...]',
#                      [2138, 2197): 'All four teams are level with one point each from one game.']
# Length: 23, dtype: TokenSpanDtype

# %%
entity_mentions = tp.io.conll.iob_to_spans(tokens)
entity_mentions
# Out:
#                                     span ent_type
# 0                      [19, 24): 'JAPAN'      LOC
# 1                      [40, 45): 'CHINA'      PER
# 2                [66, 77): 'Nadim Ladki'      PER
# 3                     [78, 84): 'AL-AIN'      LOC
# 4      [86, 106): 'United Arab Emirates'      LOC
# 5                    [118, 123): 'Japan'      LOC
# 6                [151, 160): 'Asian Cup'     MISC
# 7                    [196, 201): 'Syria'      LOC
# 8                    [249, 254): 'China'      LOC
# 9               [363, 373): 'Uzbekistan'      LOC
# 10                   [375, 380): 'China'      LOC
# 11                   [468, 473): 'Uzbek'     MISC
# 12           [482, 495): 'Igor Shkvyrin'      PER
# 13                 [580, 587): 'Chinese'     MISC
# 14          [618, 632): 'Oleg Shatskiku'      PER
# 15                  [747, 753): 'Soviet'     MISC
# 16               [781, 790): 'Asian Cup'     MISC
# 17             [842, 853): 'Asian Games'     MISC
# 18              [875, 885): 'Uzbekistan'      LOC
# 19                   [982, 987): 'Japan'      LOC
# 20                 [1072, 1077): 'Syria'      LOC
# 21         [1079, 1092): 'Takuya Takagi'      PER
# 22  [1148, 1168): 'Hiroshige Yanagimoto'      PER
# 23                [1187, 1193): 'Syrian'     MISC
# 24           [1216, 1227): 'Salem Bitar'      PER
# 25                 [1328, 1333): 'Syria'      LOC
# 26          [1360, 1372): 'Hassan Abbas'      PER
# 27                 [1489, 1494): 'Bitar'      PER
# 28        [1503, 1517): 'Nader Jokhadar'      PER
# 29                 [1528, 1533): 'Syria'      LOC
# 30                 [1592, 1597): 'Japan'      LOC
# 31                [1621, 1627): 'Syrian'     MISC
# 32                [1686, 1692): 'Syrian'     MISC
# 33                 [1702, 1707): 'Bitar'      PER
# 34                 [1749, 1754): 'Japan'      LOC
# 35              [1761, 1769): 'Shu Kamo'      PER
# 36                [1784, 1790): 'Syrian'     MISC
# 37               [1825, 1832): 'Syrians'     MISC
# 38                 [1928, 1933): 'Japan'      LOC
# 39             [1951, 1960): 'World Cup'     MISC
# 40                  [2001, 2005): 'FIFA'      ORG
# 41                   [2056, 2059): 'UAE'      LOC
# 42                [2065, 2071): 'Kuwait'      LOC
# 43           [2076, 2087): 'South Korea'      LOC
# 44             [2096, 2105): 'Indonesia'      LOC

# %%
entity_sentence_pairs = tp.spanner.contain_join(pd.Series(sentences), entity_mentions["span"], "sentence", "span")
entity_sentence_pairs
# Out:
#                                              sentence  \
# 0   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...
# 1   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...
# 2                             [66, 77): 'Nadim Ladki'
# 3   [78, 117): 'AL-AIN, United Arab Emirates 1996-...
# 4   [78, 117): 'AL-AIN, United Arab Emirates 1996-...
# 5   [118, 244): 'Japan began the defence of their ...
# 6   [118, 244): 'Japan began the defence of their ...
# 7   [118, 244): 'Japan began the defence of their ...
# 8   [245, 374): 'But China saw their luck desert t...
# 9   [245, 374): 'But China saw their luck desert t...
# 10  [375, 617): 'China controlled most of the matc...
# 11  [375, 617): 'China controlled most of the matc...
# 12  [375, 617): 'China controlled most of the matc...
# 13  [375, 617): 'China controlled most of the matc...
# 14  [618, 735): 'Oleg Shatskiku made sure of the w...
# 15  [736, 821): 'The former Soviet republic was pl...
# 16  [736, 821): 'The former Soviet republic was pl...
# 17  [822, 917): 'Despite winning the Asian Games t...
# 18  [822, 917): 'Despite winning the Asian Games t...
# 19  [918, 1078): 'Two goals from defensive errors ...
# 20  [918, 1078): 'Two goals from defensive errors ...
# 21  [1079, 1291): 'Takuya Takagi scored the winner...
# 22  [1079, 1291): 'Takuya Takagi scored the winner...
# 23  [1079, 1291): 'Takuya Takagi scored the winner...
# 24  [1079, 1291): 'Takuya Takagi scored the winner...
# 25  [1292, 1350): 'It was the second costly blunde...
# 26  [1351, 1502): 'Defender Hassan Abbas rose to i...
# 27  [1351, 1502): 'Defender Hassan Abbas rose to i...
# 28  [1503, 1591): 'Nader Jokhadar had given Syria ...
# 29  [1503, 1591): 'Nader Jokhadar had given Syria ...
# 30  [1592, 1701): 'Japan then laid siege to the Sy...
# 31  [1592, 1701): 'Japan then laid siege to the Sy...
# 32  [1592, 1701): 'Japan then laid siege to the Sy...
# 33  [1702, 1748): 'Bitar pulled off fine saves whe...
# 34  [1749, 1820): 'Japan coach Shu Kamo said: ' ' ...
# 35  [1749, 1820): 'Japan coach Shu Kamo said: ' ' ...
# 36  [1749, 1820): 'Japan coach Shu Kamo said: ' ' ...
# 37  [1821, 1925): 'The Syrians scored early and th...
# 38  [1928, 2049): 'Japan, co-hosts of the World Cu...
# 39  [1928, 2049): 'Japan, co-hosts of the World Cu...
# 40  [1928, 2049): 'Japan, co-hosts of the World Cu...
# 41  [2050, 2137): 'Hosts UAE play Kuwait and South...
# 42  [2050, 2137): 'Hosts UAE play Kuwait and South...
# 43  [2050, 2137): 'Hosts UAE play Kuwait and South...
# 44  [2050, 2137): 'Hosts UAE play Kuwait and South...
#
#                                     span
# 0                      [19, 24): 'JAPAN'
# 1                      [40, 45): 'CHINA'
# 2                [66, 77): 'Nadim Ladki'
# 3                     [78, 84): 'AL-AIN'
# 4      [86, 106): 'United Arab Emirates'
# 5                    [118, 123): 'Japan'
# 6                [151, 160): 'Asian Cup'
# 7                    [196, 201): 'Syria'
# 8                    [249, 254): 'China'
# 9               [363, 373): 'Uzbekistan'
# 10                   [375, 380): 'China'
# 11                   [468, 473): 'Uzbek'
# 12           [482, 495): 'Igor Shkvyrin'
# 13                 [580, 587): 'Chinese'
# 14          [618, 632): 'Oleg Shatskiku'
# 15                  [747, 753): 'Soviet'
# 16               [781, 790): 'Asian Cup'
# 17             [842, 853): 'Asian Games'
# 18              [875, 885): 'Uzbekistan'
# 19                   [982, 987): 'Japan'
# 20                 [1072, 1077): 'Syria'
# 21         [1079, 1092): 'Takuya Takagi'
# 22  [1148, 1168): 'Hiroshige Yanagimoto'
# 23                [1187, 1193): 'Syrian'
# 24           [1216, 1227): 'Salem Bitar'
# 25                 [1328, 1333): 'Syria'
# 26          [1360, 1372): 'Hassan Abbas'
# 27                 [1489, 1494): 'Bitar'
# 28        [1503, 1517): 'Nader Jokhadar'
# 29                 [1528, 1533): 'Syria'
# 30                 [1592, 1597): 'Japan'
# 31                [1621, 1627): 'Syrian'
# 32                [1686, 1692): 'Syrian'
# 33                 [1702, 1707): 'Bitar'
# 34                 [1749, 1754): 'Japan'
# 35              [1761, 1769): 'Shu Kamo'
# 36                [1784, 1790): 'Syrian'
# 37               [1825, 1832): 'Syrians'
# 38                 [1928, 1933): 'Japan'
# 39             [1951, 1960): 'World Cup'
# 40                  [2001, 2005): 'FIFA'
# 41                   [2056, 2059): 'UAE'
# 42                [2065, 2071): 'Kuwait'
# 43           [2076, 2087): 'South Korea'
# 44             [2096, 2105): 'Indonesia'

# %%
entity_mentions = entity_mentions.merge(entity_sentence_pairs)
entity_mentions
# Out:
#                                     span ent_type  \
# 0                      [19, 24): 'JAPAN'      LOC
# 1                      [40, 45): 'CHINA'      PER
# 2                [66, 77): 'Nadim Ladki'      PER
# 3                     [78, 84): 'AL-AIN'      LOC
# 4      [86, 106): 'United Arab Emirates'      LOC
# 5                    [118, 123): 'Japan'      LOC
# 6                [151, 160): 'Asian Cup'     MISC
# 7                    [196, 201): 'Syria'      LOC
# 8                    [249, 254): 'China'      LOC
# 9               [363, 373): 'Uzbekistan'      LOC
# 10                   [375, 380): 'China'      LOC
# 11                   [468, 473): 'Uzbek'     MISC
# 12           [482, 495): 'Igor Shkvyrin'      PER
# 13                 [580, 587): 'Chinese'     MISC
# 14          [618, 632): 'Oleg Shatskiku'      PER
# 15                  [747, 753): 'Soviet'     MISC
# 16               [781, 790): 'Asian Cup'     MISC
# 17             [842, 853): 'Asian Games'     MISC
# 18              [875, 885): 'Uzbekistan'      LOC
# 19                   [982, 987): 'Japan'      LOC
# 20                 [1072, 1077): 'Syria'      LOC
# 21         [1079, 1092): 'Takuya Takagi'      PER
# 22  [1148, 1168): 'Hiroshige Yanagimoto'      PER
# 23                [1187, 1193): 'Syrian'     MISC
# 24           [1216, 1227): 'Salem Bitar'      PER
# 25                 [1328, 1333): 'Syria'      LOC
# 26          [1360, 1372): 'Hassan Abbas'      PER
# 27                 [1489, 1494): 'Bitar'      PER
# 28        [1503, 1517): 'Nader Jokhadar'      PER
# 29                 [1528, 1533): 'Syria'      LOC
# 30                 [1592, 1597): 'Japan'      LOC
# 31                [1621, 1627): 'Syrian'     MISC
# 32                [1686, 1692): 'Syrian'     MISC
# 33                 [1702, 1707): 'Bitar'      PER
# 34                 [1749, 1754): 'Japan'      LOC
# 35              [1761, 1769): 'Shu Kamo'      PER
# 36                [1784, 1790): 'Syrian'     MISC
# 37               [1825, 1832): 'Syrians'     MISC
# 38                 [1928, 1933): 'Japan'      LOC
# 39             [1951, 1960): 'World Cup'     MISC
# 40                  [2001, 2005): 'FIFA'      ORG
# 41                   [2056, 2059): 'UAE'      LOC
# 42                [2065, 2071): 'Kuwait'      LOC
# 43           [2076, 2087): 'South Korea'      LOC
# 44             [2096, 2105): 'Indonesia'      LOC
#
#                                              sentence
# 0   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...
# 1   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...
# 2                             [66, 77): 'Nadim Ladki'
# 3   [78, 117): 'AL-AIN, United Arab Emirates 1996-...
# 4   [78, 117): 'AL-AIN, United Arab Emirates 1996-...
# 5   [118, 244): 'Japan began the defence of their ...
# 6   [118, 244): 'Japan began the defence of their ...
# 7   [118, 244): 'Japan began the defence of their ...
# 8   [245, 374): 'But China saw their luck desert t...
# 9   [245, 374): 'But China saw their luck desert t...
# 10  [375, 617): 'China controlled most of the matc...
# 11  [375, 617): 'China controlled most of the matc...
# 12  [375, 617): 'China controlled most of the matc...
# 13  [375, 617): 'China controlled most of the matc...
# 14  [618, 735): 'Oleg Shatskiku made sure of the w...
# 15  [736, 821): 'The former Soviet republic was pl...
# 16  [736, 821): 'The former Soviet republic was pl...
# 17  [822, 917): 'Despite winning the Asian Games t...
# 18  [822, 917): 'Despite winning the Asian Games t...
# 19  [918, 1078): 'Two goals from defensive errors ...
# 20  [918, 1078): 'Two goals from defensive errors ...
# 21  [1079, 1291): 'Takuya Takagi scored the winner...
# 22  [1079, 1291): 'Takuya Takagi scored the winner...
# 23  [1079, 1291): 'Takuya Takagi scored the winner...
# 24  [1079, 1291): 'Takuya Takagi scored the winner...
# 25  [1292, 1350): 'It was the second costly blunde...
# 26  [1351, 1502): 'Defender Hassan Abbas rose to i...
# 27  [1351, 1502): 'Defender Hassan Abbas rose to i...
# 28  [1503, 1591): 'Nader Jokhadar had given Syria ...
# 29  [1503, 1591): 'Nader Jokhadar had given Syria ...
# 30  [1592, 1701): 'Japan then laid siege to the Sy...
# 31  [1592, 1701): 'Japan then laid siege to the Sy...
# 32  [1592, 1701): 'Japan then laid siege to the Sy...
# 33  [1702, 1748): 'Bitar pulled off fine saves whe...
# 34  [1749, 1820): 'Japan coach Shu Kamo said: ' ' ...
# 35  [1749, 1820): 'Japan coach Shu Kamo said: ' ' ...
# 36  [1749, 1820): 'Japan coach Shu Kamo said: ' ' ...
# 37  [1821, 1925): 'The Syrians scored early and th...
# 38  [1928, 2049): 'Japan, co-hosts of the World Cu...
# 39  [1928, 2049): 'Japan, co-hosts of the World Cu...
# 40  [1928, 2049): 'Japan, co-hosts of the World Cu...
# 41  [2050, 2137): 'Hosts UAE play Kuwait and South...
# 42  [2050, 2137): 'Hosts UAE play Kuwait and South...
# 43  [2050, 2137): 'Hosts UAE play Kuwait and South...
# 44  [2050, 2137): 'Hosts UAE play Kuwait and South...

# %%
entity_mentions["sentence_id"] = entity_mentions["sentence"].array.begin
entity_mentions
# Out:
#                                     span ent_type  \
# 0                      [19, 24): 'JAPAN'      LOC
# 1                      [40, 45): 'CHINA'      PER
# 2                [66, 77): 'Nadim Ladki'      PER
# 3                     [78, 84): 'AL-AIN'      LOC
# 4      [86, 106): 'United Arab Emirates'      LOC
# 5                    [118, 123): 'Japan'      LOC
# 6                [151, 160): 'Asian Cup'     MISC
# 7                    [196, 201): 'Syria'      LOC
# 8                    [249, 254): 'China'      LOC
# 9               [363, 373): 'Uzbekistan'      LOC
# 10                   [375, 380): 'China'      LOC
# 11                   [468, 473): 'Uzbek'     MISC
# 12           [482, 495): 'Igor Shkvyrin'      PER
# 13                 [580, 587): 'Chinese'     MISC
# 14          [618, 632): 'Oleg Shatskiku'      PER
# 15                  [747, 753): 'Soviet'     MISC
# 16               [781, 790): 'Asian Cup'     MISC
# 17             [842, 853): 'Asian Games'     MISC
# 18              [875, 885): 'Uzbekistan'      LOC
# 19                   [982, 987): 'Japan'      LOC
# 20                 [1072, 1077): 'Syria'      LOC
# 21         [1079, 1092): 'Takuya Takagi'      PER
# 22  [1148, 1168): 'Hiroshige Yanagimoto'      PER
# 23                [1187, 1193): 'Syrian'     MISC
# 24           [1216, 1227): 'Salem Bitar'      PER
# 25                 [1328, 1333): 'Syria'      LOC
# 26          [1360, 1372): 'Hassan Abbas'      PER
# 27                 [1489, 1494): 'Bitar'      PER
# 28        [1503, 1517): 'Nader Jokhadar'      PER
# 29                 [1528, 1533): 'Syria'      LOC
# 30                 [1592, 1597): 'Japan'      LOC
# 31                [1621, 1627): 'Syrian'     MISC
# 32                [1686, 1692): 'Syrian'     MISC
# 33                 [1702, 1707): 'Bitar'      PER
# 34                 [1749, 1754): 'Japan'      LOC
# 35              [1761, 1769): 'Shu Kamo'      PER
# 36                [1784, 1790): 'Syrian'     MISC
# 37               [1825, 1832): 'Syrians'     MISC
# 38                 [1928, 1933): 'Japan'      LOC
# 39             [1951, 1960): 'World Cup'     MISC
# 40                  [2001, 2005): 'FIFA'      ORG
# 41                   [2056, 2059): 'UAE'      LOC
# 42                [2065, 2071): 'Kuwait'      LOC
# 43           [2076, 2087): 'South Korea'      LOC
# 44             [2096, 2105): 'Indonesia'      LOC
#
#                                              sentence  sentence_id
# 0   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...           11
# 1   [11, 65): 'SOCCER- JAPAN GET LUCKY WIN, CHINA ...           11
# 2                             [66, 77): 'Nadim Ladki'           66
# 3   [78, 117): 'AL-AIN, United Arab Emirates 1996-...           78
# 4   [78, 117): 'AL-AIN, United Arab Emirates 1996-...           78
# 5   [118, 244): 'Japan began the defence of their ...          118
# 6   [118, 244): 'Japan began the defence of their ...          118
# 7   [118, 244): 'Japan began the defence of their ...          118
# 8   [245, 374): 'But China saw their luck desert t...          245
# 9   [245, 374): 'But China saw their luck desert t...          245
# 10  [375, 617): 'China controlled most of the matc...          375
# 11  [375, 617): 'China controlled most of the matc...          375
# 12  [375, 617): 'China controlled most of the matc...          375
# 13  [375, 617): 'China controlled most of the matc...          375
# 14  [618, 735): 'Oleg Shatskiku made sure of the w...          618
# 15  [736, 821): 'The former Soviet republic was pl...          736
# 16  [736, 821): 'The former Soviet republic was pl...          736
# 17  [822, 917): 'Despite winning the Asian Games t...          822
# 18  [822, 917): 'Despite winning the Asian Games t...          822
# 19  [918, 1078): 'Two goals from defensive errors ...          918
# 20  [918, 1078): 'Two goals from defensive errors ...          918
# 21  [1079, 1291): 'Takuya Takagi scored the winner...         1079
# 22  [1079, 1291): 'Takuya Takagi scored the winner...         1079
# 23  [1079, 1291): 'Takuya Takagi scored the winner...         1079
# 24  [1079, 1291): 'Takuya Takagi scored the winner...         1079
# 25  [1292, 1350): 'It was the second costly blunde...         1292
# 26  [1351, 1502): 'Defender Hassan Abbas rose to i...         1351
# 27  [1351, 1502): 'Defender Hassan Abbas rose to i...         1351
# 28  [1503, 1591): 'Nader Jokhadar had given Syria ...         1503
# 29  [1503, 1591): 'Nader Jokhadar had given Syria ...         1503
# 30  [1592, 1701): 'Japan then laid siege to the Sy...         1592
# 31  [1592, 1701): 'Japan then laid siege to the Sy...         1592
# 32  [1592, 1701): 'Japan then laid siege to the Sy...         1592
# 33  [1702, 1748): 'Bitar pulled off fine saves whe...         1702
# 34  [1749, 1820): 'Japan coach Shu Kamo said: ' ' ...         1749
# 35  [1749, 1820): 'Japan coach Shu Kamo said: ' ' ...         1749
# 36  [1749, 1820): 'Japan coach Shu Kamo said: ' ' ...         1749
# 37  [1821, 1925): 'The Syrians scored early and th...         1821
# 38  [1928, 2049): 'Japan, co-hosts of the World Cu...         1928
# 39  [1928, 2049): 'Japan, co-hosts of the World Cu...         1928
# 40  [1928, 2049): 'Japan, co-hosts of the World Cu...         1928
# 41  [2050, 2137): 'Hosts UAE play Kuwait and South...         2050
# 42  [2050, 2137): 'Hosts UAE play Kuwait and South...         2050
# 43  [2050, 2137): 'Hosts UAE play Kuwait and South...         2050
# 44  [2050, 2137): 'Hosts UAE play Kuwait and South...         2050

# %% [markdown]
# We can take a closer look at what the ```span``` column might look like in context by viewing the column alone as the SpanArray datatype.

# %%
entity_mentions["span"].array
# Out:
# <TokenSpanArray>
# [                   [19, 24): 'JAPAN',                    [40, 45): 'CHINA',
#               [66, 77): 'Nadim Ladki',                   [78, 84): 'AL-AIN',
#     [86, 106): 'United Arab Emirates',                  [118, 123): 'Japan',
#               [151, 160): 'Asian Cup',                  [196, 201): 'Syria',
#                   [249, 254): 'China',             [363, 373): 'Uzbekistan',
#                   [375, 380): 'China',                  [468, 473): 'Uzbek',
#           [482, 495): 'Igor Shkvyrin',                [580, 587): 'Chinese',
#          [618, 632): 'Oleg Shatskiku',                 [747, 753): 'Soviet',
#               [781, 790): 'Asian Cup',            [842, 853): 'Asian Games',
#              [875, 885): 'Uzbekistan',                  [982, 987): 'Japan',
#                 [1072, 1077): 'Syria',        [1079, 1092): 'Takuya Takagi',
#  [1148, 1168): 'Hiroshige Yanagimoto',               [1187, 1193): 'Syrian',
#           [1216, 1227): 'Salem Bitar',                [1328, 1333): 'Syria',
#          [1360, 1372): 'Hassan Abbas',                [1489, 1494): 'Bitar',
#        [1503, 1517): 'Nader Jokhadar',                [1528, 1533): 'Syria',
#                 [1592, 1597): 'Japan',               [1621, 1627): 'Syrian',
#                [1686, 1692): 'Syrian',                [1702, 1707): 'Bitar',
#                 [1749, 1754): 'Japan',             [1761, 1769): 'Shu Kamo',
#                [1784, 1790): 'Syrian',              [1825, 1832): 'Syrians',
#                 [1928, 1933): 'Japan',            [1951, 1960): 'World Cup',
#                  [2001, 2005): 'FIFA',                  [2056, 2059): 'UAE',
#                [2065, 2071): 'Kuwait',          [2076, 2087): 'South Korea',
#             [2096, 2105): 'Indonesia']
# Length: 45, dtype: TokenSpanDtype

# %% [markdown]
# We don't really want to visualize every column in our dataframe as we're only interested in viewing the entity classifications. The next step is to drop any columns we don't care about.

# %% [markdown]
# Now that our data is prepared for analysis, we can load it up in our widget.

# %%
widget = tp.jupyter.render_dataframe(entity_mentions.drop(columns=["sentence"]))
#widget = tp.jupyter.render_dataframe(entity_mentions, interactive_columns=["ent_type"])
widget.display()
# Out:
# Output(_dom_classes=('tep--dfwidget--output',))

# %% [markdown]
# If we want to view this widget interactively, we can pass in the additional parameter ```interactive_columns``` with an array of column names we want to become interactive widgets.
#
# One thing you may notice in the above widgets is that the column ```ent_type``` is editable via a text box. This is fine, but there is a more appropriate way to interact with categorical data.

# %%
categorical = pd.Categorical(df_doc["ent_type"], categories=["PER", "LOC", "ORG", "MISC"])
df_doc["ent_type"] = categorical
df_doc.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b0e13c43ee7f> in <module>
# ----> 1 categorical = pd.Categorical(df_doc["ent_type"], categories=["PER", "LOC", "ORG", "MISC"])
#       2 df_doc["ent_type"] = categorical
#       3 df_doc.dtypes
#
# NameError: name 'df_doc' is not defined

# %%
widget = tp.jupyter.render_dataframe(df_doc, interactive_columns=["ent_type"])
widget.display()

# %%
corrected_entities = entity_mentions.copy(True)
new_types = corrected_entities["ent_type"].copy()
new_types[widget._metadata_column] = "ORG"
corrected_entities["new_type"] = new_types
corrected_entities

# %%
out_df = widget.to_dataframe()
out_df

# %%
Named Entity Recognition, Named Entity Extraction - Entity Mention Extraction
