# %% [markdown]
# # Watson NLP Example for Text Extensions for Pandas
#
# ## Introduction
#
# This demo shows how to use the `watson` module from Text Extension for Pandas to
# process a Watson NLP response from the IBM cloud into Pandas DataFrames for analysis.
# Pandas is the de facto tool for data science and ...
# https://github.com/CODAIT/text-extensions-for-pandas
#
# The notebook is broken up into 2 parts:
#
# **Part 1:** Shows how to authenticate with the IBM Watson SDK and make a request with the
# Watson NLU API. The response is then processed by Text Extensions for Pandas to convert
# the JSON response into several Pandas DataFrames.
#
# **Part 2:** Will go deeper into the data received from Watson NLU and show how to do
# analytics with the DataFrames from Text Extensions for Pandas
#
#
# ## Authentication
#
# This demo uses the IBM Watson Python SDK to perform authentication on the IBM Cloud with the
# `IAMAuthenticator`. See https://github.com/watson-developer-cloud/python-sdk#iam for more
# information. To properly authenticate with IBM Cloud, please set the environment variable
# `IBM_API_KEY` with your correct apikey to make requests to `ibm_watson.NaturalLanguageUnderstandingV1`.

# %%
# INITIALIZATION BOILERPLATE

# The Jupyter kernel for this notebook usually starts up inside the notebooks
# directory, but the text_extensions_for_pandas package code is in the parent
# directory. Add that parent directory to the front of the Python include path.
import sys
if (sys.path[0] != ".."):
    sys.path[0] = ".."

import json
import os
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, CategoriesOptions, ConceptsOptions, EmotionOptions, EntitiesOptions, KeywordsOptions, \
    MetadataOptions, RelationsOptions, SemanticRolesOptions, SentimentOptions, SyntaxOptions, SyntaxOptionsTokens
import pandas as pd
import text_extensions_for_pandas as tp
from text_extensions_for_pandas.io.watson import watson_nlu_parse_response

# %%
# Retrieve the APIKEY for authentication
apikey = os.environ.get("IBM_API_KEY")
if apikey is None:
    raise ValueError("Expected apikey in the environment variable 'IBM_API_KEY'")

# Set the service URL for your IBM Cloud instance
ibm_cloud_service_url = 'https://api.us-south.natural-language-understanding.watson.cloud.ibm.com/instances/21b9b875-4ddb-46ad-bb22-d78747622ca7'

# %%
# Initialize the authenticator for making requests
authenticator = IAMAuthenticator(apikey)
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url(ibm_cloud_service_url)

# %% [markdown]
# # Part 1: Processing the Watson NLU Response to Pandas
#
# The responses should be in the form of decoded JSON Python and the following features
# will be processed into DataFrames:
#
# * entities
# * keywords
# * relations
# * semantic_roles
# * syntax with sentences and tokens
#
# See https://cloud.ibm.com/apidocs/natural-language-understanding?code=python#text-analytics-features

# %%
# Make the request
response = natural_language_understanding.analyze(
    url='https://raw.githubusercontent.com/CODAIT/text-extensions-for-pandas/master/resources/holy_grail.txt',
    features=Features(
        #categories=CategoriesOptions(limit=3), 
        #concepts=ConceptsOptions(limit=3), 
        #emotion=EmotionOptions(targets=['grail']),
        entities=EntitiesOptions(sentiment=True,limit=3),
        keywords=KeywordsOptions(sentiment=True,emotion=True,limit=3),
        #metadata=MetadataOptions(),
        relations=RelationsOptions(),
        semantic_roles=SemanticRolesOptions(limit=3),
        #sentiment=SentimentOptions(targets=['Arthur']),
        syntax=SyntaxOptions(sentences=True, tokens=SyntaxOptionsTokens(lemma=True, part_of_speech=True))  # Experimental
    )).get_result()

# %%
# View response as JSON
print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 5338,
#     "features": 4
#   },
#   "syntax": {
#     "tokens": [
#       {
#         "text": "Monty",
#         "part_of_speech": "PROPN",
#         "location": [
#           0,
#           5
#         ]
#       },
#       {
#         "text": "Python",
#         "part_of_speech": "PROPN",
#         "location": [
#           6,
#           12
#         ],
#         "lemma": "python"
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           13,
#           16
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           17,
#           20
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "Holy",
#         "part_of_speech": "PROPN",
#         "location": [
#           21,
#           25
#         ]
#       },
#       {
#         "text": "Grail",
#         "part_of_speech": "PROPN",
#         "location": [
#           26,
#           31
#         ]
#       },
#       {
#         "text": "is",
#         "part_of_speech": "AUX",
#         "location": [
#           32,
#           34
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "a",
#         "part_of_speech": "DET",
#         "location": [
#           35,
#           36
#         ],
#         "lemma": "a"
#       },
#       {
#         "text": "1975",
#         "part_of_speech": "NUM",
#         "location": [
#           37,
#           41
#         ]
#       },
#       {
#         "text": "British",
#         "part_of_speech": "ADJ",
#         "location": [
#           42,
#           49
#         ],
#         "lemma": "British"
#       },
#       {
#         "text": "comedy",
#         "part_of_speech": "NOUN",
#         "location": [
#           50,
#           56
#         ],
#         "lemma": "comedy"
#       },
#       {
#         "text": "film",
#         "part_of_speech": "NOUN",
#         "location": [
#           57,
#           61
#         ],
#         "lemma": "film"
#       },
#       {
#         "text": "concerning",
#         "part_of_speech": "VERB",
#         "location": [
#           62,
#           72
#         ],
#         "lemma": "concern"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           73,
#           76
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "Arthurian",
#         "part_of_speech": "PROPN",
#         "location": [
#           77,
#           86
#         ]
#       },
#       {
#         "text": "legend",
#         "part_of_speech": "NOUN",
#         "location": [
#           87,
#           93
#         ],
#         "lemma": "legend"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           93,
#           94
#         ]
#       },
#       {
#         "text": "written",
#         "part_of_speech": "VERB",
#         "location": [
#           95,
#           102
#         ],
#         "lemma": "write"
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           103,
#           106
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "performed",
#         "part_of_speech": "VERB",
#         "location": [
#           107,
#           116
#         ],
#         "lemma": "perform"
#       },
#       {
#         "text": "by",
#         "part_of_speech": "ADP",
#         "location": [
#           117,
#           119
#         ],
#         "lemma": "by"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           120,
#           123
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "Monty",
#         "part_of_speech": "PROPN",
#         "location": [
#           124,
#           129
#         ]
#       },
#       {
#         "text": "Python",
#         "part_of_speech": "PROPN",
#         "location": [
#           130,
#           136
#         ],
#         "lemma": "python"
#       },
#       {
#         "text": "comedy",
#         "part_of_speech": "NOUN",
#         "location": [
#           137,
#           143
#         ],
#         "lemma": "comedy"
#       },
#       {
#         "text": "group",
#         "part_of_speech": "NOUN",
#         "location": [
#           144,
#           149
#         ],
#         "lemma": "group"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           150,
#           152
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "Graham",
#         "part_of_speech": "PROPN",
#         "location": [
#           153,
#           159
#         ]
#       },
#       {
#         "text": "Chapman",
#         "part_of_speech": "PROPN",
#         "location": [
#           160,
#           167
#         ],
#         "lemma": "chapman"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           167,
#           168
#         ]
#       },
#       {
#         "text": "John",
#         "part_of_speech": "PROPN",
#         "location": [
#           169,
#           173
#         ]
#       },
#       {
#         "text": "Cleese",
#         "part_of_speech": "PROPN",
#         "location": [
#           174,
#           180
#         ]
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           180,
#           181
#         ]
#       },
#       {
#         "text": "Terry",
#         "part_of_speech": "PROPN",
#         "location": [
#           182,
#           187
#         ],
#         "lemma": "terry"
#       },
#       {
#         "text": "Gilliam",
#         "part_of_speech": "PROPN",
#         "location": [
#           188,
#           195
#         ]
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           195,
#           196
#         ]
#       },
#       {
#         "text": "Eric",
#         "part_of_speech": "PROPN",
#         "location": [
#           197,
#           201
#         ]
#       },
#       {
#         "text": "Idle",
#         "part_of_speech": "PROPN",
#         "location": [
#           202,
#           206
#         ],
#         "lemma": "idle"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           206,
#           207
#         ]
#       },
#       {
#         "text": "Terry",
#         "part_of_speech": "PROPN",
#         "location": [
#           208,
#           213
#         ],
#         "lemma": "terry"
#       },
#       {
#         "text": "Jones",
#         "part_of_speech": "PROPN",
#         "location": [
#           214,
#           219
#         ]
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           220,
#           223
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "Michael",
#         "part_of_speech": "PROPN",
#         "location": [
#           224,
#           231
#         ]
#       },
#       {
#         "text": "Palin",
#         "part_of_speech": "PROPN",
#         "location": [
#           232,
#           237
#         ]
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           237,
#           238
#         ]
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           239,
#           242
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "directed",
#         "part_of_speech": "VERB",
#         "location": [
#           243,
#           251
#         ],
#         "lemma": "direct"
#       },
#       {
#         "text": "by",
#         "part_of_speech": "ADP",
#         "location": [
#           252,
#           254
#         ],
#         "lemma": "by"
#       },
#       {
#         "text": "Gilliam",
#         "part_of_speech": "PROPN",
#         "location": [
#           255,
#           262
#         ]
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           263,
#           266
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "Jones",
#         "part_of_speech": "PROPN",
#         "location": [
#           267,
#           272
#         ]
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           272,
#           273
#         ]
#       },
#       {
#         "text": "It",
#         "part_of_speech": "PRON",
#         "location": [
#           274,
#           276
#         ],
#         "lemma": "it"
#       },
#       {
#         "text": "was",
#         "part_of_speech": "AUX",
#         "location": [
#           277,
#           280
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "conceived",
#         "part_of_speech": "VERB",
#         "location": [
#           281,
#           290
#         ],
#         "lemma": "conceive"
#       },
#       {
#         "text": "during",
#         "part_of_speech": "ADP",
#         "location": [
#           291,
#           297
#         ],
#         "lemma": "during"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           298,
#           301
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "hiatus",
#         "part_of_speech": "NOUN",
#         "location": [
#           302,
#           308
#         ],
#         "lemma": "hiatus"
#       },
#       {
#         "text": "between",
#         "part_of_speech": "ADP",
#         "location": [
#           309,
#           316
#         ],
#         "lemma": "between"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           317,
#           320
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "third",
#         "part_of_speech": "ADJ",
#         "location": [
#           321,
#           326
#         ],
#         "lemma": "third"
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           327,
#           330
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "fourth",
#         "part_of_speech": "ADJ",
#         "location": [
#           331,
#           337
#         ],
#         "lemma": "fourth"
#       },
#       {
#         "text": "series",
#         "part_of_speech": "NOUN",
#         "location": [
#           338,
#           344
#         ],
#         "lemma": "series"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           345,
#           347
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "their",
#         "part_of_speech": "PRON",
#         "location": [
#           348,
#           353
#         ],
#         "lemma": "their"
#       },
#       {
#         "text": "BBC",
#         "part_of_speech": "NOUN",
#         "location": [
#           354,
#           357
#         ]
#       },
#       {
#         "text": "television",
#         "part_of_speech": "NOUN",
#         "location": [
#           358,
#           368
#         ],
#         "lemma": "television"
#       },
#       {
#         "text": "series",
#         "part_of_speech": "NOUN",
#         "location": [
#           369,
#           375
#         ],
#         "lemma": "series"
#       },
#       {
#         "text": "Monty",
#         "part_of_speech": "PROPN",
#         "location": [
#           376,
#           381
#         ]
#       },
#       {
#         "text": "Python",
#         "part_of_speech": "PROPN",
#         "location": [
#           382,
#           388
#         ],
#         "lemma": "python"
#       },
#       {
#         "text": "'s",
#         "part_of_speech": "PART",
#         "location": [
#           388,
#           390
#         ],
#         "lemma": "'s"
#       },
#       {
#         "text": "Flying",
#         "part_of_speech": "PROPN",
#         "location": [
#           391,
#           397
#         ],
#         "lemma": "flying"
#       },
#       {
#         "text": "Circus",
#         "part_of_speech": "PROPN",
#         "location": [
#           398,
#           404
#         ],
#         "lemma": "circus"
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           404,
#           405
#         ]
#       },
#       {
#         "text": "While",
#         "part_of_speech": "SCONJ",
#         "location": [
#           407,
#           412
#         ],
#         "lemma": "while"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           413,
#           416
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "group",
#         "part_of_speech": "NOUN",
#         "location": [
#           417,
#           422
#         ],
#         "lemma": "group"
#       },
#       {
#         "text": "'s",
#         "part_of_speech": "PART",
#         "location": [
#           422,
#           424
#         ],
#         "lemma": "'s"
#       },
#       {
#         "text": "first",
#         "part_of_speech": "ADJ",
#         "location": [
#           425,
#           430
#         ],
#         "lemma": "first"
#       },
#       {
#         "text": "film",
#         "part_of_speech": "NOUN",
#         "location": [
#           431,
#           435
#         ],
#         "lemma": "film"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           435,
#           436
#         ]
#       },
#       {
#         "text": "And",
#         "part_of_speech": "CCONJ",
#         "location": [
#           437,
#           440
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "Now",
#         "part_of_speech": "ADV",
#         "location": [
#           441,
#           444
#         ],
#         "lemma": "now"
#       },
#       {
#         "text": "for",
#         "part_of_speech": "ADP",
#         "location": [
#           445,
#           448
#         ],
#         "lemma": "for"
#       },
#       {
#         "text": "Something",
#         "part_of_speech": "PRON",
#         "location": [
#           449,
#           458
#         ],
#         "lemma": "something"
#       },
#       {
#         "text": "Completely",
#         "part_of_speech": "ADV",
#         "location": [
#           459,
#           469
#         ],
#         "lemma": "completely"
#       },
#       {
#         "text": "Different",
#         "part_of_speech": "ADJ",
#         "location": [
#           470,
#           479
#         ],
#         "lemma": "different"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           479,
#           480
#         ]
#       },
#       {
#         "text": "was",
#         "part_of_speech": "AUX",
#         "location": [
#           481,
#           484
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "a",
#         "part_of_speech": "DET",
#         "location": [
#           485,
#           486
#         ],
#         "lemma": "a"
#       },
#       {
#         "text": "compilation",
#         "part_of_speech": "NOUN",
#         "location": [
#           487,
#           498
#         ],
#         "lemma": "compilation"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           499,
#           501
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "sketches",
#         "part_of_speech": "NOUN",
#         "location": [
#           502,
#           510
#         ],
#         "lemma": "sketch"
#       },
#       {
#         "text": "from",
#         "part_of_speech": "ADP",
#         "location": [
#           511,
#           515
#         ],
#         "lemma": "from"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           516,
#           519
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "first",
#         "part_of_speech": "ADJ",
#         "location": [
#           520,
#           525
#         ],
#         "lemma": "first"
#       },
#       {
#         "text": "two",
#         "part_of_speech": "NUM",
#         "location": [
#           526,
#           529
#         ],
#         "lemma": "two"
#       },
#       {
#         "text": "television",
#         "part_of_speech": "NOUN",
#         "location": [
#           530,
#           540
#         ],
#         "lemma": "television"
#       },
#       {
#         "text": "series",
#         "part_of_speech": "NOUN",
#         "location": [
#           541,
#           547
#         ],
#         "lemma": "series"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           547,
#           548
#         ]
#       },
#       {
#         "text": "Holy",
#         "part_of_speech": "PROPN",
#         "location": [
#           549,
#           553
#         ]
#       },
#       {
#         "text": "Grail",
#         "part_of_speech": "PROPN",
#         "location": [
#           554,
#           559
#         ]
#       },
#       {
#         "text": "is",
#         "part_of_speech": "AUX",
#         "location": [
#           560,
#           562
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "a",
#         "part_of_speech": "DET",
#         "location": [
#           563,
#           564
#         ],
#         "lemma": "a"
#       },
#       {
#         "text": "new",
#         "part_of_speech": "ADJ",
#         "location": [
#           565,
#           568
#         ],
#         "lemma": "new"
#       },
#       {
#         "text": "story",
#         "part_of_speech": "NOUN",
#         "location": [
#           569,
#           574
#         ],
#         "lemma": "story"
#       },
#       {
#         "text": "that",
#         "part_of_speech": "PRON",
#         "location": [
#           575,
#           579
#         ],
#         "lemma": "that"
#       },
#       {
#         "text": "parodies",
#         "part_of_speech": "VERB",
#         "location": [
#           580,
#           588
#         ],
#         "lemma": "parody"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           589,
#           592
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "legend",
#         "part_of_speech": "NOUN",
#         "location": [
#           593,
#           599
#         ],
#         "lemma": "legend"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           600,
#           602
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "King",
#         "part_of_speech": "PROPN",
#         "location": [
#           603,
#           607
#         ],
#         "lemma": "king"
#       },
#       {
#         "text": "Arthur",
#         "part_of_speech": "PROPN",
#         "location": [
#           608,
#           614
#         ]
#       },
#       {
#         "text": "'s",
#         "part_of_speech": "PART",
#         "location": [
#           614,
#           616
#         ],
#         "lemma": "'s"
#       },
#       {
#         "text": "quest",
#         "part_of_speech": "NOUN",
#         "location": [
#           617,
#           622
#         ],
#         "lemma": "quest"
#       },
#       {
#         "text": "for",
#         "part_of_speech": "ADP",
#         "location": [
#           623,
#           626
#         ],
#         "lemma": "for"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           627,
#           630
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "Holy",
#         "part_of_speech": "PROPN",
#         "location": [
#           631,
#           635
#         ]
#       },
#       {
#         "text": "Grail",
#         "part_of_speech": "PROPN",
#         "location": [
#           636,
#           641
#         ]
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           641,
#           642
#         ]
#       },
#       {
#         "text": "Thirty",
#         "part_of_speech": "NUM",
#         "location": [
#           643,
#           649
#         ],
#         "lemma": "thirty"
#       },
#       {
#         "text": "years",
#         "part_of_speech": "NOUN",
#         "location": [
#           650,
#           655
#         ],
#         "lemma": "year"
#       },
#       {
#         "text": "later",
#         "part_of_speech": "ADV",
#         "location": [
#           656,
#           661
#         ],
#         "lemma": "late"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           661,
#           662
#         ]
#       },
#       {
#         "text": "Idle",
#         "part_of_speech": "PROPN",
#         "location": [
#           663,
#           667
#         ],
#         "lemma": "idle"
#       },
#       {
#         "text": "used",
#         "part_of_speech": "VERB",
#         "location": [
#           668,
#           672
#         ],
#         "lemma": "use"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           673,
#           676
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "film",
#         "part_of_speech": "NOUN",
#         "location": [
#           677,
#           681
#         ],
#         "lemma": "film"
#       },
#       {
#         "text": "as",
#         "part_of_speech": "ADP",
#         "location": [
#           682,
#           684
#         ],
#         "lemma": "as"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           685,
#           688
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "basis",
#         "part_of_speech": "NOUN",
#         "location": [
#           689,
#           694
#         ],
#         "lemma": "basis"
#       },
#       {
#         "text": "for",
#         "part_of_speech": "ADP",
#         "location": [
#           695,
#           698
#         ],
#         "lemma": "for"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           699,
#           702
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "musical",
#         "part_of_speech": "ADJ",
#         "location": [
#           703,
#           710
#         ],
#         "lemma": "musical"
#       },
#       {
#         "text": "Spamalot",
#         "part_of_speech": "PROPN",
#         "location": [
#           711,
#           719
#         ]
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           719,
#           720
#         ]
#       },
#       {
#         "text": "Monty",
#         "part_of_speech": "PROPN",
#         "location": [
#           722,
#           727
#         ]
#       },
#       {
#         "text": "Python",
#         "part_of_speech": "PROPN",
#         "location": [
#           728,
#           734
#         ],
#         "lemma": "python"
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           735,
#           738
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           739,
#           742
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "Holy",
#         "part_of_speech": "PROPN",
#         "location": [
#           743,
#           747
#         ]
#       },
#       {
#         "text": "Grail",
#         "part_of_speech": "PROPN",
#         "location": [
#           748,
#           753
#         ]
#       },
#       {
#         "text": "grossed",
#         "part_of_speech": "VERB",
#         "location": [
#           754,
#           761
#         ],
#         "lemma": "gross"
#       },
#       {
#         "text": "more",
#         "part_of_speech": "ADV",
#         "location": [
#           762,
#           766
#         ],
#         "lemma": "much"
#       },
#       {
#         "text": "than",
#         "part_of_speech": "ADP",
#         "location": [
#           767,
#           771
#         ],
#         "lemma": "than"
#       },
#       {
#         "text": "any",
#         "part_of_speech": "DET",
#         "location": [
#           772,
#           775
#         ]
#       },
#       {
#         "text": "other",
#         "part_of_speech": "ADJ",
#         "location": [
#           776,
#           781
#         ],
#         "lemma": "other"
#       },
#       {
#         "text": "British",
#         "part_of_speech": "ADJ",
#         "location": [
#           782,
#           789
#         ],
#         "lemma": "British"
#       },
#       {
#         "text": "film",
#         "part_of_speech": "NOUN",
#         "location": [
#           790,
#           794
#         ],
#         "lemma": "film"
#       },
#       {
#         "text": "exhibited",
#         "part_of_speech": "VERB",
#         "location": [
#           795,
#           804
#         ],
#         "lemma": "exhibit"
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           805,
#           807
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           808,
#           811
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "US",
#         "part_of_speech": "PROPN",
#         "location": [
#           812,
#           814
#         ]
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           815,
#           817
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "2005",
#         "part_of_speech": "NUM",
#         "location": [
#           818,
#           822
#         ]
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           822,
#           823
#         ]
#       },
#       {
#         "text": "In",
#         "part_of_speech": "ADP",
#         "location": [
#           824,
#           826
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           827,
#           830
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "US",
#         "part_of_speech": "PROPN",
#         "location": [
#           831,
#           833
#         ]
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           833,
#           834
#         ]
#       },
#       {
#         "text": "it",
#         "part_of_speech": "PRON",
#         "location": [
#           835,
#           837
#         ],
#         "lemma": "it"
#       },
#       {
#         "text": "was",
#         "part_of_speech": "AUX",
#         "location": [
#           838,
#           841
#         ],
#         "lemma": "be"
#       },
#       {
#         "text": "selected",
#         "part_of_speech": "VERB",
#         "location": [
#           842,
#           850
#         ],
#         "lemma": "select"
#       },
#       {
#         "text": "as",
#         "part_of_speech": "ADP",
#         "location": [
#           851,
#           853
#         ],
#         "lemma": "as"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           854,
#           857
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "second",
#         "part_of_speech": "ADJ",
#         "location": [
#           858,
#           864
#         ],
#         "lemma": "second"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           864,
#           865
#         ]
#       },
#       {
#         "text": "best",
#         "part_of_speech": "ADJ",
#         "location": [
#           865,
#           869
#         ],
#         "lemma": "good"
#       },
#       {
#         "text": "comedy",
#         "part_of_speech": "NOUN",
#         "location": [
#           870,
#           876
#         ],
#         "lemma": "comedy"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           877,
#           879
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "all",
#         "part_of_speech": "DET",
#         "location": [
#           880,
#           883
#         ],
#         "lemma": "all"
#       },
#       {
#         "text": "time",
#         "part_of_speech": "NOUN",
#         "location": [
#           884,
#           888
#         ],
#         "lemma": "time"
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           889,
#           891
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           892,
#           895
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "ABC",
#         "part_of_speech": "NOUN",
#         "location": [
#           896,
#           899
#         ],
#         "lemma": "ABC"
#       },
#       {
#         "text": "special",
#         "part_of_speech": "ADJ",
#         "location": [
#           900,
#           907
#         ],
#         "lemma": "special"
#       },
#       {
#         "text": "Best",
#         "part_of_speech": "ADJ",
#         "location": [
#           908,
#           912
#         ],
#         "lemma": "good"
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           913,
#           915
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "Film",
#         "part_of_speech": "NOUN",
#         "location": [
#           916,
#           920
#         ],
#         "lemma": "film"
#       },
#       {
#         "text": ":",
#         "part_of_speech": "PUNCT",
#         "location": [
#           920,
#           921
#         ],
#         "lemma": ":"
#       },
#       {
#         "text": "The",
#         "part_of_speech": "DET",
#         "location": [
#           922,
#           925
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "Greatest",
#         "part_of_speech": "PROPN",
#         "location": [
#           926,
#           934
#         ]
#       },
#       {
#         "text": "Movies",
#         "part_of_speech": "PROPN",
#         "location": [
#           935,
#           941
#         ],
#         "lemma": "movie"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           942,
#           944
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "Our",
#         "part_of_speech": "PRON",
#         "location": [
#           945,
#           948
#         ],
#         "lemma": "our"
#       },
#       {
#         "text": "Time",
#         "part_of_speech": "NOUN",
#         "location": [
#           949,
#           953
#         ],
#         "lemma": "time"
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           953,
#           954
#         ]
#       },
#       {
#         "text": "In",
#         "part_of_speech": "ADP",
#         "location": [
#           955,
#           957
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           958,
#           961
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "UK",
#         "part_of_speech": "PROPN",
#         "location": [
#           962,
#           964
#         ]
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           964,
#           965
#         ]
#       },
#       {
#         "text": "readers",
#         "part_of_speech": "NOUN",
#         "location": [
#           966,
#           973
#         ],
#         "lemma": "reader"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           974,
#           976
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "Total",
#         "part_of_speech": "ADJ",
#         "location": [
#           977,
#           982
#         ],
#         "lemma": "total"
#       },
#       {
#         "text": "Film",
#         "part_of_speech": "NOUN",
#         "location": [
#           983,
#           987
#         ],
#         "lemma": "film"
#       },
#       {
#         "text": "magazine",
#         "part_of_speech": "NOUN",
#         "location": [
#           988,
#           996
#         ],
#         "lemma": "magazine"
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           997,
#           999
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "2000",
#         "part_of_speech": "NUM",
#         "location": [
#           1000,
#           1004
#         ]
#       },
#       {
#         "text": "ranked",
#         "part_of_speech": "VERB",
#         "location": [
#           1005,
#           1011
#         ],
#         "lemma": "rank"
#       },
#       {
#         "text": "it",
#         "part_of_speech": "PRON",
#         "location": [
#           1012,
#           1014
#         ],
#         "lemma": "it"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           1015,
#           1018
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "fifth",
#         "part_of_speech": "ADJ",
#         "location": [
#           1019,
#           1024
#         ],
#         "lemma": "fifth"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1024,
#           1025
#         ]
#       },
#       {
#         "text": "greatest",
#         "part_of_speech": "ADJ",
#         "location": [
#           1025,
#           1033
#         ],
#         "lemma": "great"
#       },
#       {
#         "text": "comedy",
#         "part_of_speech": "NOUN",
#         "location": [
#           1034,
#           1040
#         ],
#         "lemma": "comedy"
#       },
#       {
#         "text": "film",
#         "part_of_speech": "NOUN",
#         "location": [
#           1041,
#           1045
#         ],
#         "lemma": "film"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           1046,
#           1048
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "all",
#         "part_of_speech": "DET",
#         "location": [
#           1049,
#           1052
#         ],
#         "lemma": "all"
#       },
#       {
#         "text": "time",
#         "part_of_speech": "NOUN",
#         "location": [
#           1053,
#           1057
#         ],
#         "lemma": "time"
#       },
#       {
#         "text": ";",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1057,
#           1058
#         ]
#       },
#       {
#         "text": "[",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1058,
#           1059
#         ]
#       },
#       {
#         "text": "4",
#         "part_of_speech": "NUM",
#         "location": [
#           1059,
#           1060
#         ]
#       },
#       {
#         "text": "]",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1060,
#           1061
#         ]
#       },
#       {
#         "text": "a",
#         "part_of_speech": "DET",
#         "location": [
#           1062,
#           1063
#         ],
#         "lemma": "a"
#       },
#       {
#         "text": "similar",
#         "part_of_speech": "ADJ",
#         "location": [
#           1064,
#           1071
#         ],
#         "lemma": "similar"
#       },
#       {
#         "text": "poll",
#         "part_of_speech": "NOUN",
#         "location": [
#           1072,
#           1076
#         ],
#         "lemma": "poll"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           1077,
#           1079
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "Channel",
#         "part_of_speech": "PROPN",
#         "location": [
#           1080,
#           1087
#         ],
#         "lemma": "channel"
#       },
#       {
#         "text": "4",
#         "part_of_speech": "NUM",
#         "location": [
#           1088,
#           1089
#         ]
#       },
#       {
#         "text": "viewers",
#         "part_of_speech": "NOUN",
#         "location": [
#           1090,
#           1097
#         ],
#         "lemma": "viewer"
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           1098,
#           1100
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "2006",
#         "part_of_speech": "NUM",
#         "location": [
#           1101,
#           1105
#         ]
#       },
#       {
#         "text": "placed",
#         "part_of_speech": "VERB",
#         "location": [
#           1106,
#           1112
#         ],
#         "lemma": "place"
#       },
#       {
#         "text": "it",
#         "part_of_speech": "PRON",
#         "location": [
#           1113,
#           1115
#         ],
#         "lemma": "it"
#       },
#       {
#         "text": "sixth",
#         "part_of_speech": "ADV",
#         "location": [
#           1116,
#           1121
#         ],
#         "lemma": "sixth"
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1121,
#           1122
#         ]
#       },
#       {
#         "text": "[",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1122,
#           1123
#         ]
#       },
#       {
#         "text": "5",
#         "part_of_speech": "NUM",
#         "location": [
#           1123,
#           1124
#         ]
#       },
#       {
#         "text": "]",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1124,
#           1125
#         ]
#       },
#       {
#         "text": "In",
#         "part_of_speech": "ADP",
#         "location": [
#           1127,
#           1129
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "AD",
#         "part_of_speech": "PROPN",
#         "location": [
#           1130,
#           1132
#         ],
#         "lemma": "ad"
#       },
#       {
#         "text": "932",
#         "part_of_speech": "NUM",
#         "location": [
#           1133,
#           1136
#         ]
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1136,
#           1137
#         ]
#       },
#       {
#         "text": "King",
#         "part_of_speech": "PROPN",
#         "location": [
#           1138,
#           1142
#         ],
#         "lemma": "king"
#       },
#       {
#         "text": "Arthur",
#         "part_of_speech": "PROPN",
#         "location": [
#           1143,
#           1149
#         ]
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           1150,
#           1153
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "his",
#         "part_of_speech": "PRON",
#         "location": [
#           1154,
#           1157
#         ],
#         "lemma": "his"
#       },
#       {
#         "text": "squire",
#         "part_of_speech": "NOUN",
#         "location": [
#           1158,
#           1164
#         ],
#         "lemma": "squire"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1164,
#           1165
#         ]
#       },
#       {
#         "text": "Patsy",
#         "part_of_speech": "PROPN",
#         "location": [
#           1166,
#           1171
#         ],
#         "lemma": "patsy"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1171,
#           1172
#         ]
#       },
#       {
#         "text": "travel",
#         "part_of_speech": "NOUN",
#         "location": [
#           1173,
#           1179
#         ],
#         "lemma": "travel"
#       },
#       {
#         "text": "throughout",
#         "part_of_speech": "ADP",
#         "location": [
#           1180,
#           1190
#         ],
#         "lemma": "throughout"
#       },
#       {
#         "text": "Britain",
#         "part_of_speech": "PROPN",
#         "location": [
#           1191,
#           1198
#         ]
#       },
#       {
#         "text": "searching",
#         "part_of_speech": "VERB",
#         "location": [
#           1199,
#           1208
#         ],
#         "lemma": "search"
#       },
#       {
#         "text": "for",
#         "part_of_speech": "ADP",
#         "location": [
#           1209,
#           1212
#         ],
#         "lemma": "for"
#       },
#       {
#         "text": "men",
#         "part_of_speech": "NOUN",
#         "location": [
#           1213,
#           1216
#         ],
#         "lemma": "man"
#       },
#       {
#         "text": "to",
#         "part_of_speech": "PART",
#         "location": [
#           1217,
#           1219
#         ],
#         "lemma": "to"
#       },
#       {
#         "text": "join",
#         "part_of_speech": "VERB",
#         "location": [
#           1220,
#           1224
#         ],
#         "lemma": "join"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           1225,
#           1228
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "Knights",
#         "part_of_speech": "PROPN",
#         "location": [
#           1229,
#           1236
#         ],
#         "lemma": "knight"
#       },
#       {
#         "text": "of",
#         "part_of_speech": "ADP",
#         "location": [
#           1237,
#           1239
#         ],
#         "lemma": "of"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           1240,
#           1243
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "Round",
#         "part_of_speech": "ADJ",
#         "location": [
#           1244,
#           1249
#         ],
#         "lemma": "round"
#       },
#       {
#         "text": "Table",
#         "part_of_speech": "NOUN",
#         "location": [
#           1250,
#           1255
#         ],
#         "lemma": "table"
#       },
#       {
#         "text": ".",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1255,
#           1256
#         ]
#       },
#       {
#         "text": "Along",
#         "part_of_speech": "ADP",
#         "location": [
#           1257,
#           1262
#         ],
#         "lemma": "along"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           1263,
#           1266
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "way",
#         "part_of_speech": "NOUN",
#         "location": [
#           1267,
#           1270
#         ],
#         "lemma": "way"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1270,
#           1271
#         ]
#       },
#       {
#         "text": "he",
#         "part_of_speech": "PRON",
#         "location": [
#           1272,
#           1274
#         ],
#         "lemma": "he"
#       },
#       {
#         "text": "recruits",
#         "part_of_speech": "VERB",
#         "location": [
#           1275,
#           1283
#         ],
#         "lemma": "recruit"
#       },
#       {
#         "text": "Sir",
#         "part_of_speech": "PROPN",
#         "location": [
#           1284,
#           1287
#         ],
#         "lemma": "sir"
#       },
#       {
#         "text": "Bedevere",
#         "part_of_speech": "VERB",
#         "location": [
#           1288,
#           1296
#         ]
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           1297,
#           1300
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "Wise",
#         "part_of_speech": "PROPN",
#         "location": [
#           1301,
#           1305
#         ],
#         "lemma": "wise"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1305,
#           1306
#         ]
#       },
#       {
#         "text": "Sir",
#         "part_of_speech": "PROPN",
#         "location": [
#           1307,
#           1310
#         ],
#         "lemma": "sir"
#       },
#       {
#         "text": "Lancelot",
#         "part_of_speech": "PROPN",
#         "location": [
#           1311,
#           1319
#         ]
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           1320,
#           1323
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "Brave",
#         "part_of_speech": "ADJ",
#         "location": [
#           1324,
#           1329
#         ],
#         "lemma": "brave"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1329,
#           1330
#         ]
#       },
#       {
#         "text": "Sir",
#         "part_of_speech": "PROPN",
#         "location": [
#           1331,
#           1334
#         ],
#         "lemma": "sir"
#       },
#       {
#         "text": "Galahad",
#         "part_of_speech": "PROPN",
#         "location": [
#           1335,
#           1342
#         ]
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           1343,
#           1346
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "Pure",
#         "part_of_speech": "PROPN",
#         "location": [
#           1347,
#           1351
#         ]
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1351,
#           1352
#         ]
#       },
#       {
#         "text": "Sir",
#         "part_of_speech": "PROPN",
#         "location": [
#           1353,
#           1356
#         ],
#         "lemma": "sir"
#       },
#       {
#         "text": "Robin",
#         "part_of_speech": "PROPN",
#         "location": [
#           1357,
#           1362
#         ],
#         "lemma": "robin"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           1363,
#           1366
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "Not",
#         "part_of_speech": "ADV",
#         "location": [
#           1367,
#           1370
#         ],
#         "lemma": "not"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1370,
#           1371
#         ]
#       },
#       {
#         "text": "Quite",
#         "part_of_speech": "ADV",
#         "location": [
#           1371,
#           1376
#         ],
#         "lemma": "quite"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1376,
#           1377
#         ]
#       },
#       {
#         "text": "So",
#         "part_of_speech": "ADV",
#         "location": [
#           1377,
#           1379
#         ],
#         "lemma": "so"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1379,
#           1380
#         ]
#       },
#       {
#         "text": "Brave",
#         "part_of_speech": "ADJ",
#         "location": [
#           1380,
#           1385
#         ],
#         "lemma": "brave"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1385,
#           1386
#         ]
#       },
#       {
#         "text": "as",
#         "part_of_speech": "ADP",
#         "location": [
#           1386,
#           1388
#         ],
#         "lemma": "as"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1388,
#           1389
#         ]
#       },
#       {
#         "text": "Sir",
#         "part_of_speech": "NOUN",
#         "location": [
#           1389,
#           1392
#         ],
#         "lemma": "sir"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1392,
#           1393
#         ]
#       },
#       {
#         "text": "Lancelot",
#         "part_of_speech": "PROPN",
#         "location": [
#           1393,
#           1401
#         ]
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1401,
#           1402
#         ]
#       },
#       {
#         "text": "and",
#         "part_of_speech": "CCONJ",
#         "location": [
#           1403,
#           1406
#         ],
#         "lemma": "and"
#       },
#       {
#         "text": "Sir",
#         "part_of_speech": "PROPN",
#         "location": [
#           1407,
#           1410
#         ],
#         "lemma": "sir"
#       },
#       {
#         "text": "Not",
#         "part_of_speech": "ADV",
#         "location": [
#           1411,
#           1414
#         ],
#         "lemma": "not"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1414,
#           1415
#         ]
#       },
#       {
#         "text": "Appearing",
#         "part_of_speech": "NOUN",
#         "location": [
#           1415,
#           1424
#         ]
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1424,
#           1425
#         ]
#       },
#       {
#         "text": "in",
#         "part_of_speech": "ADP",
#         "location": [
#           1425,
#           1427
#         ],
#         "lemma": "in"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1427,
#           1428
#         ]
#       },
#       {
#         "text": "this",
#         "part_of_speech": "PRON",
#         "location": [
#           1428,
#           1432
#         ],
#         "lemma": "this"
#       },
#       {
#         "text": "-",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1432,
#           1433
#         ]
#       },
#       {
#         "text": "Film",
#         "part_of_speech": "NOUN",
#         "location": [
#           1433,
#           1437
#         ],
#         "lemma": "film"
#       },
#       {
#         "text": ",",
#         "part_of_speech": "PUNCT",
#         "location": [
#           1437,
#           1438
#         ]
#       },
#       {
#         "text": "along",
#         "part_of_speech": "ADV",
#         "location": [
#           1439,
#           1444
#         ],
#         "lemma": "along"
#       },
#       {
#         "text": "with",
#         "part_of_speech": "ADP",
#         "location": [
#           1445,
#           1449
#         ],
#         "lemma": "with"
#       },
#       {
#         "text": "their",
#         "part_of_speech": "PRON",
#         "location": [
#           1450,
#           1455
#         ],
#         "lemma": "their"
#       },
#       {
#         "text": "squires",
#         "part_of_speech": "NOUN",
#         "location": [
#           1456,
#           1463
# ...
#             4503
#           ],
#           "entities": [
#             {
#               "type": "EventCommunication",
#               "text": "responds"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "locatedAt",
#       "sentence": "During Arthur's turn, he responds to the bridge-keeper's last question with a question of his own which stumps the bridge-keeper.",
#       "score": 0.691983,
#       "arguments": [
#         {
#           "text": "he",
#           "location": [
#             4492,
#             4494
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "King Arthur"
#             }
#           ]
#         },
#         {
#           "text": "bridge",
#           "location": [
#             4511,
#             4517
#           ],
#           "entities": [
#             {
#               "type": "Facility",
#               "text": "bridge"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "locatedAt",
#       "sentence": "During Arthur's turn, he responds to the bridge-keeper's last question with a question of his own which stumps the bridge-keeper.",
#       "score": 0.603077,
#       "arguments": [
#         {
#           "text": "his",
#           "location": [
#             4560,
#             4563
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "King Arthur"
#             }
#           ]
#         },
#         {
#           "text": "bridge",
#           "location": [
#             4585,
#             4591
#           ],
#           "entities": [
#             {
#               "type": "Facility",
#               "text": "bridge"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "locatedAt",
#       "sentence": "As a result, the man from Scene 24 is thrown into the gorge, and Arthur and Bedevere cross.",
#       "score": 0.506421,
#       "arguments": [
#         {
#           "text": "man",
#           "location": [
#             4617,
#             4620
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "King Arthur"
#             }
#           ]
#         },
#         {
#           "text": "Scene",
#           "location": [
#             4626,
#             4631
#           ],
#           "entities": [
#             {
#               "type": "Location",
#               "text": "Scene"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "authorOf",
#       "sentence": "Thirty years later, Idle used the film as the basis for the musical Spamalot.",
#       "score": 0.852951,
#       "arguments": [
#         {
#           "text": "Idle",
#           "location": [
#             663,
#             667
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Eric Idle"
#             }
#           ]
#         },
#         {
#           "text": "film",
#           "location": [
#             677,
#             681
#           ],
#           "entities": [
#             {
#               "type": "TitleWork",
#               "text": "comedy"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "partOfMany",
#       "sentence": "When Arthur and Bedevere reach the bridge's end, they cannot find Lancelot, unaware he has been arrested by the police investigating the historian's death.",
#       "score": 0.781408,
#       "arguments": [
#         {
#           "text": "Bedevere",
#           "location": [
#             4709,
#             4717
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Bedevere"
#             }
#           ]
#         },
#         {
#           "text": "they",
#           "location": [
#             4742,
#             4746
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "they"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "affectedBy",
#       "sentence": "When Arthur and Bedevere reach the bridge's end, they cannot find Lancelot, unaware he has been arrested by the police investigating the historian's death.",
#       "score": 0.922504,
#       "arguments": [
#         {
#           "text": "he",
#           "location": [
#             4777,
#             4779
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "King Arthur"
#             }
#           ]
#         },
#         {
#           "text": "arrested",
#           "location": [
#             4789,
#             4797
#           ],
#           "entities": [
#             {
#               "type": "EventCustody",
#               "text": "arrests"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "affectedBy",
#       "sentence": "Just as they are charging in to attack, a large force of police shows up, arrests Arthur and Bedevere for the historian's death, and shuts down the film's production.",
#       "score": 0.63673,
#       "arguments": [
#         {
#           "text": "Arthur",
#           "location": [
#             5190,
#             5196
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "King Arthur"
#             }
#           ]
#         },
#         {
#           "text": "arrests",
#           "location": [
#             5182,
#             5189
#           ],
#           "entities": [
#             {
#               "type": "EventCustody",
#               "text": "arrests"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "agentOf",
#       "sentence": "When Arthur and Bedevere reach the bridge's end, they cannot find Lancelot, unaware he has been arrested by the police investigating the historian's death.",
#       "score": 0.876697,
#       "arguments": [
#         {
#           "text": "police",
#           "location": [
#             4805,
#             4811
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Grail"
#             }
#           ]
#         },
#         {
#           "text": "investigating",
#           "location": [
#             4812,
#             4825
#           ],
#           "entities": [
#             {
#               "type": "EventLegal",
#               "text": "investigating"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "affectedBy",
#       "sentence": "When Arthur and Bedevere reach the bridge's end, they cannot find Lancelot, unaware he has been arrested by the police investigating the historian's death.",
#       "score": 0.591005,
#       "arguments": [
#         {
#           "text": "historian",
#           "location": [
#             4830,
#             4839
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "King Arthur"
#             }
#           ]
#         },
#         {
#           "text": "investigating",
#           "location": [
#             4812,
#             4825
#           ],
#           "entities": [
#             {
#               "type": "EventLegal",
#               "text": "investigating"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "employedBy",
#       "sentence": "After being driven to retreat by showers of manure, they amass a large army of knights and prepare to assault the castle.",
#       "score": 0.582838,
#       "arguments": [
#         {
#           "text": "knights",
#           "location": [
#             5065,
#             5072
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "knights"
#             }
#           ]
#         },
#         {
#           "text": "army",
#           "location": [
#             5057,
#             5061
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "army",
#               "disambiguation": {
#                 "subtype": [
#                   "Military"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "affectedBy",
#       "sentence": "After being driven to retreat by showers of manure, they amass a large army of knights and prepare to assault the castle.",
#       "score": 0.805495,
#       "arguments": [
#         {
#           "text": "castle",
#           "location": [
#             5100,
#             5106
#           ],
#           "entities": [
#             {
#               "type": "Facility",
#               "text": "castle"
#             }
#           ]
#         },
#         {
#           "text": "assault",
#           "location": [
#             5088,
#             5095
#           ],
#           "entities": [
#             {
#               "type": "EventViolence",
#               "text": "assault"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "agentOf",
#       "sentence": "Just as they are charging in to attack, a large force of police shows up, arrests Arthur and Bedevere for the historian's death, and shuts down the film's production.",
#       "score": 0.616224,
#       "arguments": [
#         {
#           "text": "they",
#           "location": [
#             5116,
#             5120
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "soldiers"
#             }
#           ]
#         },
#         {
#           "text": "attack",
#           "location": [
#             5140,
#             5146
#           ],
#           "entities": [
#             {
#               "type": "EventViolence",
#               "text": "attack"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "partOfMany",
#       "sentence": "In the US, it was selected as the second-best comedy of all time in the ABC special Best in Film: The Greatest Movies of Our Time.",
#       "score": 0.41441,
#       "arguments": [
#         {
#           "text": "The Greatest Movies of Our Time",
#           "location": [
#             922,
#             953
#           ],
#           "entities": [
#             {
#               "type": "TitleWork",
#               "text": "The Greatest Movies of Our Time"
#             }
#           ]
#         },
#         {
#           "text": "comedy",
#           "location": [
#             870,
#             876
#           ],
#           "entities": [
#             {
#               "type": "TitleWork",
#               "text": "comedy"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "timeOf",
#       "sentence": "In the UK, readers of Total Film magazine in 2000 ranked it the fifth-greatest comedy film of all time;[4] a similar poll of Channel 4 viewers in 2006 placed it sixth.",
#       "score": 0.508347,
#       "arguments": [
#         {
#           "text": "2000",
#           "location": [
#             1000,
#             1004
#           ],
#           "entities": [
#             {
#               "type": "Date",
#               "text": "2000"
#             }
#           ]
#         },
#         {
#           "text": "film",
#           "location": [
#             1041,
#             1045
#           ],
#           "entities": [
#             {
#               "type": "TitleWork",
#               "text": "comedy"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "partOfMany",
#       "sentence": "Along the way, he recruits Sir Bedevere the Wise, Sir Lancelot the Brave, Sir Galahad the Pure, Sir Robin the Not-Quite-So-Brave-as-Sir-Lancelot, and Sir Not-Appearing-in-this-Film, along with their squires and Robin's troubadours.",
#       "score": 0.610221,
#       "arguments": [
#         {
#           "text": "Galahad",
#           "location": [
#             1335,
#             1342
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Galahad"
#             }
#           ]
#         },
#         {
#           "text": "their",
#           "location": [
#             1450,
#             1455
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "their"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "partOfMany",
#       "sentence": "Along the way, he recruits Sir Bedevere the Wise, Sir Lancelot the Brave, Sir Galahad the Pure, Sir Robin the Not-Quite-So-Brave-as-Sir-Lancelot, and Sir Not-Appearing-in-this-Film, along with their squires and Robin's troubadours.",
#       "score": 0.710112,
#       "arguments": [
#         {
#           "text": "Lancelot",
#           "location": [
#             1393,
#             1401
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Lancelot"
#             }
#           ]
#         },
#         {
#           "text": "their",
#           "location": [
#             1450,
#             1455
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "their"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "parentOf",
#       "sentence": "Along the way, he recruits Sir Bedevere the Wise, Sir Lancelot the Brave, Sir Galahad the Pure, Sir Robin the Not-Quite-So-Brave-as-Sir-Lancelot, and Sir Not-Appearing-in-this-Film, along with their squires and Robin's troubadours.",
#       "score": 0.3821,
#       "arguments": [
#         {
#           "text": "their",
#           "location": [
#             1450,
#             1455
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "their"
#             }
#           ]
#         },
#         {
#           "text": "squires",
#           "location": [
#             1456,
#             1463
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "squires"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "residesIn",
#       "sentence": "Arthur leads the men to Camelot, but upon further consideration (thanks to a musical number) he decides not to go there because it is \"a silly place\".",
#       "score": 0.492869,
#       "arguments": [
#         {
#           "text": "Arthur",
#           "location": [
#             1489,
#             1495
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "King Arthur"
#             }
#           ]
#         },
#         {
#           "text": "Camelot",
#           "location": [
#             1513,
#             1520
#           ],
#           "entities": [
#             {
#               "type": "GeopoliticalEntity",
#               "text": "Camelot"
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "language": "en",
#   "keywords": [
#     {
#       "text": "legend of King Arthur",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.746411,
#       "emotion": {
#         "sadness": 0.175057,
#         "joy": 0.691404,
#         "fear": 0.058051,
#         "disgust": 0.031335,
#         "anger": 0.071927
#       },
#       "count": 1
#     },
#     {
#       "text": "Sir Lancelot",
#       "sentiment": {
#         "score": 0.835873,
#         "label": "positive"
#       },
#       "relevance": 0.642571,
#       "emotion": {
#         "sadness": 0.046902,
#         "joy": 0.810654,
#         "fear": 0.01634,
#         "disgust": 0.095661,
#         "anger": 0.021033
#       },
#       "count": 1
#     },
#     {
#       "text": "King Arthur",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.642235,
#       "emotion": {
#         "sadness": 0.09149,
#         "joy": 0.747356,
#         "fear": 0.043658,
#         "disgust": 0.033299,
#         "anger": 0.112061
#       },
#       "count": 1
#     }
#   ],
#   "entities": [
#     {
#       "type": "Person",
#       "text": "Arthur",
#       "sentiment": {
#         "score": -0.312834,
#         "mixed": "1",
#         "label": "negative"
#       },
#       "relevance": 0.956097,
#       "count": 12,
#       "confidence": 1
#     },
#     {
#       "type": "Person",
#       "text": "Lancelot",
#       "sentiment": {
#         "score": 0.835873,
#         "label": "positive"
#       },
#       "relevance": 0.678523,
#       "count": 5,
#       "confidence": 1
#     },
#     {
#       "type": "Person",
#       "text": "Monty Python",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.644313,
#       "count": 2,
#       "confidence": 0.977538
#     }
#   ]
# }

# %%
# Get the response as processed Pandas DataFrames
dfs = watson_nlu_parse_response(response)

# %%
# Created DataFrames from the response
dfs.keys()
# Out:
# dict_keys(['entities', 'keywords', 'relations', 'semantic_roles', 'syntax'])

# %% [markdown]
# ### View the response as DataFrames

# %%
dfs['keywords']
# Out:
#    count  emotion.anger  emotion.disgust  emotion.fear  emotion.joy  \
# 0      1       0.071927         0.031335      0.058051     0.691404
# 1      1       0.021033         0.095661      0.016340     0.810654
# 2      1       0.112061         0.033299      0.043658     0.747356
#
#    emotion.sadness  relevance sentiment.label  sentiment.score  \
# 0         0.175057   0.746411         neutral         0.000000
# 1         0.046902   0.642571        positive         0.835873
# 2         0.091490   0.642235         neutral         0.000000
#
#                     text
# 0  legend of King Arthur
# 1           Sir Lancelot
# 2            King Arthur

# %%
dfs['entities']
# Out:
#    confidence  count  relevance sentiment.label sentiment.mixed  \
# 0    1.000000     12   0.956097        negative               1
# 1    1.000000      5   0.678523        positive            None
# 2    0.977538      2   0.644313         neutral            None
#
#    sentiment.score          text    type
# 0        -0.312834        Arthur  Person
# 1         0.835873      Lancelot  Person
# 2         0.000000  Monty Python  Person

# %%
dfs['relations']
# Out:
#        score                                           sentence          type  \
# 0   0.462615  Monty Python and the Holy Grail is a 1975 Brit...        timeOf
# 1   0.339446  Arthur leads the men to Camelot, but upon furt...     locatedAt
# 2   0.604304  As they turn away, God (an image of W. G. Grac...    affectedBy
# 3   0.304596  Searching the land for clues to the Grail's lo...     locatedAt
# 4   0.895035  Searching the land for clues to the Grail's lo...    employedBy
# 5   0.903545  Arthur and Bedevere eventually reach the Castl...    employedBy
# 6   0.945371  Searching the land for clues to the Grail's lo...       agentOf
# 7   0.943395  A modern-day historian filming a documentary d...       agentOf
# 8   0.600505  Sir Robin avoids a fight with a Three-Headed K...       agentOf
# 9   0.542254  Lancelot, after receiving an arrow-shot note f...     locatedAt
# 10  0.581076  Lancelot, after receiving an arrow-shot note f...      parentOf
# 11  0.474501  They meet Tim the Enchanter, who directs them ...    partOfMany
# 12  0.817482  Monty Python and the Holy Grail is a 1975 Brit...       basedIn
# 13  0.765512  They meet Tim the Enchanter, who directs them ...     locatedAt
# 14  0.565815  They meet Tim the Enchanter, who directs them ...     locatedAt
# 15  0.947217  Fatally underestimating its lethal prowess, th...       agentOf
# 16  0.587099  Fatally underestimating its lethal prowess, th...    affectedBy
# 17  0.791427  Arthur uses the "Holy Hand Grenade of Antioch"...      authorOf
# 18  0.692562  After barely escaping a giant animated monster...    partOfMany
# 19  0.467027  After barely escaping a giant animated monster...  hasAttribute
# 20  0.996934  During Arthur's turn, he responds to the bridg...       agentOf
# 21  0.691983  During Arthur's turn, he responds to the bridg...     locatedAt
# 22  0.603077  During Arthur's turn, he responds to the bridg...     locatedAt
# 23  0.506421  As a result, the man from Scene 24 is thrown i...     locatedAt
# 24  0.852951  Thirty years later, Idle used the film as the ...      authorOf
# 25  0.781408  When Arthur and Bedevere reach the bridge's en...    partOfMany
# 26  0.922504  When Arthur and Bedevere reach the bridge's en...    affectedBy
# 27  0.636730  Just as they are charging in to attack, a larg...    affectedBy
# 28  0.876697  When Arthur and Bedevere reach the bridge's en...       agentOf
# 29  0.591005  When Arthur and Bedevere reach the bridge's en...    affectedBy
# 30  0.582838  After being driven to retreat by showers of ma...    employedBy
# 31  0.805495  After being driven to retreat by showers of ma...    affectedBy
# 32  0.616224  Just as they are charging in to attack, a larg...       agentOf
# 33  0.414410  In the US, it was selected as the second-best ...    partOfMany
# 34  0.508347  In the UK, readers of Total Film magazine in 2...        timeOf
# 35  0.610221  Along the way, he recruits Sir Bedevere the Wi...    partOfMany
# 36  0.710112  Along the way, he recruits Sir Bedevere the Wi...    partOfMany
# 37  0.382100  Along the way, he recruits Sir Bedevere the Wi...      parentOf
# 38  0.492869  Arthur leads the men to Camelot, but upon furt...     residesIn
#
#    arguments.0.entities.disambiguation.subtype  \
# 0                                         None
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                         None
# 5                                         None
# 6                                         None
# 7                                         None
# 8                                         None
# 9                                         None
# 10                                        None
# 11                                        None
# 12                                        None
# 13                                        None
# 14                                        None
# 15                                        None
# 16                                        None
# 17                                        None
# 18                                        None
# 19                                        None
# 20                                        None
# 21                                        None
# 22                                        None
# 23                                        None
# 24                                        None
# 25                                        None
# 26                                        None
# 27                                        None
# 28                                        None
# 29                                        None
# 30                                        None
# 31                                        None
# 32                                        None
# 33                                        None
# 34                                        None
# 35                                        None
# 36                                        None
# 37                                        None
# 38                                        None
#
#    arguments.1.entities.disambiguation.subtype  \
# 0                                         None
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                    [Country]
# 5                                    [Country]
# 6                                         None
# 7                                         None
# 8                                         None
# 9                                         None
# 10                                        None
# 11                                        None
# 12                                        None
# 13                                        None
# 14                                        None
# 15                                        None
# 16                                        None
# 17                                        None
# 18                                        None
# 19                                        None
# 20                                        None
# 21                                        None
# 22                                        None
# 23                                        None
# 24                                        None
# 25                                        None
# 26                                        None
# 27                                        None
# 28                                        None
# 29                                        None
# 30                                  [Military]
# 31                                        None
# 32                                        None
# 33                                        None
# 34                                        None
# 35                                        None
# 36                                        None
# 37                                        None
# 38                                        None
#
#           arguments.0.entities.text arguments.1.entities.text  \
# 0                              1975                    comedy
# 1                               men                   Camelot
# 2                             their                    speaks
# 3                             Grail                  location
# 4                          soldiers                    French
# 5                          soldiers                    French
# 6                          soldiers                     claim
# 7                             Grail             investigation
# 8                             Robin                   arguing
# 9                          Lancelot                    castle
# 10                      King Arthur                     whose
# 11                Tim the Enchanter                   knights
# 12        Monty Python comedy group            Graham Chapman
# 13                Tim the Enchanter                      cave
# 14                             cave                  location
# 15                          knights                    attack
# 16             Rabbit of Caerbannog                    attack
# 17                  Brother Maynard   Hand Grenade of Antioch
# 18                  Brother Maynard                   knights
# 19                  Brother Maynard              heart attack
# 20                      King Arthur                  responds
# 21                      King Arthur                    bridge
# 22                      King Arthur                    bridge
# 23                      King Arthur                     Scene
# 24                        Eric Idle                    comedy
# 25                         Bedevere                      they
# 26                      King Arthur                   arrests
# 27                      King Arthur                   arrests
# 28                            Grail             investigating
# 29                      King Arthur             investigating
# 30                          knights                      army
# 31                           castle                   assault
# 32                         soldiers                    attack
# 33  The Greatest Movies of Our Time                    comedy
# 34                             2000                    comedy
# 35                          Galahad                     their
# 36                         Lancelot                     their
# 37                            their                   squires
# 38                      King Arthur                   Camelot
#
#    arguments.0.entities.type arguments.1.entities.type arguments.0.location  \
# 0                       Date                 TitleWork             [37, 41]
# 1                     Person        GeopoliticalEntity         [1506, 1509]
# 2                     Person        EventCommunication         [1699, 1703]
# 3               Organization                  Location         [1794, 1799]
# 4                     Person        GeopoliticalEntity         [1872, 1880]
# 5                     Person        GeopoliticalEntity         [4952, 4960]
# 6                     Person        EventCommunication         [1881, 1884]
# 7               Organization                EventLegal         [2455, 2461]
# 8                     Person        EventCommunication         [2656, 2661]
# 9                     Person                  Facility         [2894, 2902]
# 10                    Person                    Person         [3163, 3169]
# 11                    Person                    Person         [3346, 3349]
# 12              Organization        GeopoliticalEntity           [124, 149]
# 13                    Person                  Facility         [3346, 3349]
# 14                  Facility                  Location         [3373, 3378]
# 15                    Person             EventViolence         [3541, 3548]
# 16              Organization             EventViolence         [3560, 3566]
# 17                    Person                 TitleWork         [3676, 3691]
# 18                    Person                    Person         [3967, 3982]
# 19                    Person           HealthCondition         [3988, 3996]
# 20                    Person        EventCommunication         [4492, 4494]
# 21                    Person                  Facility         [4492, 4494]
# 22                    Person                  Facility         [4560, 4563]
# 23                    Person                  Location         [4617, 4620]
# 24                    Person                 TitleWork           [663, 667]
# 25                    Person                    Person         [4709, 4717]
# 26                    Person              EventCustody         [4777, 4779]
# 27                    Person              EventCustody         [5190, 5196]
# 28              Organization                EventLegal         [4805, 4811]
# 29                    Person                EventLegal         [4830, 4839]
# 30                    Person              Organization         [5065, 5072]
# 31                  Facility             EventViolence         [5100, 5106]
# 32                    Person             EventViolence         [5116, 5120]
# 33                 TitleWork                 TitleWork           [922, 953]
# 34                      Date                 TitleWork         [1000, 1004]
# 35                    Person                    Person         [1335, 1342]
# 36                    Person                    Person         [1393, 1401]
# 37                    Person                    Person         [1450, 1455]
# 38                    Person        GeopoliticalEntity         [1489, 1495]
#
#    arguments.1.location                 arguments.0.text  \
# 0              [57, 61]                             1975
# 1          [1513, 1520]                              men
# 2          [1689, 1695]                             them
# 3          [1802, 1810]                            Grail
# 4          [1865, 1871]                         soldiers
# 5          [4945, 4951]                         soldiers
# 6          [1885, 1890]                              who
# 7          [2462, 2475]                           police
# 8          [2740, 2747]                            Robin
# 9          [3038, 3044]                         Lancelot
# 10         [3157, 3162]                           father
# 11         [3358, 3362]                              who
# 12           [153, 167]        Monty Python comedy group
# 13         [3368, 3372]                              who
# 14         [3383, 3391]                            where
# 15         [3549, 3555]                          knights
# 16         [3549, 3555]                           Rabbit
# 17         [3638, 3661]                  Brother Maynard
# 18         [4052, 4056]                  Brother Maynard
# 19         [4003, 4015]                         animator
# 20         [4495, 4503]                               he
# 21         [4511, 4517]                               he
# 22         [4585, 4591]                              his
# 23         [4626, 4631]                              man
# 24           [677, 681]                             Idle
# 25         [4742, 4746]                         Bedevere
# 26         [4789, 4797]                               he
# 27         [5182, 5189]                           Arthur
# 28         [4812, 4825]                           police
# 29         [4812, 4825]                        historian
# 30         [5057, 5061]                          knights
# 31         [5088, 5095]                           castle
# 32         [5140, 5146]                             they
# 33           [870, 876]  The Greatest Movies of Our Time
# 34         [1041, 1045]                             2000
# 35         [1450, 1455]                          Galahad
# 36         [1450, 1455]                         Lancelot
# 37         [1456, 1463]                            their
# 38         [1513, 1520]                           Arthur
#
#            arguments.1.text
# 0                      film
# 1                   Camelot
# 2                    speaks
# 3                  location
# 4                    French
# 5                    French
# 6                     claim
# 7             investigation
# 8                   arguing
# 9                    castle
# 10                    whose
# 11                     them
# 12           Graham Chapman
# 13                     cave
# 14                 location
# 15                   attack
# 16                   attack
# 17  Hand Grenade of Antioch
# 18                     they
# 19             heart attack
# 20                 responds
# 21                   bridge
# 22                   bridge
# 23                    Scene
# 24                     film
# 25                     they
# 26                 arrested
# 27                  arrests
# 28            investigating
# 29            investigating
# 30                     army
# 31                  assault
# 32                   attack
# 33                   comedy
# 34                     film
# 35                    their
# 36                    their
# 37                  squires
# 38                  Camelot

# %%
dfs['syntax']
# Out:
#         lemma part_of_speech                 char_span  \
# 0        None          PROPN           [0, 5): 'Monty'
# 1      python          PROPN         [6, 12): 'Python'
# 2         and          CCONJ           [13, 16): 'and'
# 3         the            DET           [17, 20): 'the'
# 4        None          PROPN          [21, 25): 'Holy'
# ...       ...            ...                       ...
# 1076  officer           NOUN  [5306, 5314): 'officers'
# 1077    break           VERB  [5315, 5323): 'breaking'
# 1078      the            DET       [5324, 5327): 'the'
# 1079   camera           NOUN    [5328, 5334): 'camera'
# 1080     None          PUNCT         [5334, 5335): '.'
#
#                     token_span  \
# 0              [0, 5): 'Monty'
# 1            [6, 12): 'Python'
# 2              [13, 16): 'and'
# 3              [17, 20): 'the'
# 4             [21, 25): 'Holy'
# ...                        ...
# 1076  [5306, 5314): 'officers'
# 1077  [5315, 5323): 'breaking'
# 1078       [5324, 5327): 'the'
# 1079    [5328, 5334): 'camera'
# 1080         [5334, 5335): '.'
#
#                                                sentence
# 0     [0, 273): 'Monty Python and the Holy Grail is ...
# 1     [0, 273): 'Monty Python and the Holy Grail is ...
# 2     [0, 273): 'Monty Python and the Holy Grail is ...
# 3     [0, 273): 'Monty Python and the Holy Grail is ...
# 4     [0, 273): 'Monty Python and the Holy Grail is ...
# ...                                                 ...
# 1076  [5275, 5335): 'The movie ends with one of the ...
# 1077  [5275, 5335): 'The movie ends with one of the ...
# 1078  [5275, 5335): 'The movie ends with one of the ...
# 1079  [5275, 5335): 'The movie ends with one of the ...
# 1080  [5275, 5335): 'The movie ends with one of the ...
#
# [1081 rows x 5 columns]

# %% [markdown]
# # Part 2: NLU Syntax Analysis using DataFrames
#
# Now we will do some analysis on the NLU Syntax result using the Pandas DataFrame

# %%
df = dfs['syntax']

# Retrieve sentence information from the above dataframe
sentences = pd.DataFrame({"sentence": df["sentence"].unique()})
sentences
# Out:
#                                              sentence
# 0   [0, 273): 'Monty Python and the Holy Grail is ...
# 1   [274, 405): 'It was conceived during the hiatu...
# 2   [407, 642): 'While the group's first film, And...
# 3   [643, 720): 'Thirty years later, Idle used the...
# 4   [722, 823): 'Monty Python and the Holy Grail g...
# 5   [824, 954): 'In the US, it was selected as the...
# 6   [955, 1122): 'In the UK, readers of Total Film...
# 7   [1122, 1256): '[5] In AD 932, King Arthur and ...
# 8   [1257, 1488): 'Along the way, he recruits Sir ...
# 9   [1489, 1639): 'Arthur leads the men to Camelot...
# 10  [1640, 1756): 'As they turn away, God (an imag...
# 11  [1758, 1935): 'Searching the land for clues to...
# 12  [1936, 2199): 'After being driven back by a sh...
# 13  [2200, 2309): 'Arthur decides that the knights...
# 14  [2310, 2476): 'A modern-day historian filming ...
# 15  [2478, 2649): 'On the knights' travels, Arthur...
# 16                                 [2649, 2651): '".'
# 17  [2652, 2748): 'Sir Robin avoids a fight with a...
# 18  [2749, 2893): 'Sir Galahad is led by a grail-s...
# 19  [2894, 3196): 'Lancelot, after receiving an ar...
# 20  [3198, 3316): 'Arthur and his knights regroup,...
# 21  [3317, 3427): 'They meet Tim the Enchanter, wh...
# 22  [3428, 3492): 'The entrance to the cave is gua...
# 23  [3493, 3615): 'Fatally underestimating its let...
# 24  [3616, 3717): 'Arthur uses the "Holy Hand Gren...
# 25  [3718, 3905): 'Inside the cave, they find an i...
# 26  [3907, 4094): 'After barely escaping a giant a...
# 27  [4095, 4252): 'As they approach the Bridge of ...
# 28  [4253, 4330): 'Lancelot goes first, easily ans...
# 29  [4331, 4469): 'Robin is surprised by an unexpe...
# 30  [4470, 4599): 'During Arthur's turn, he respon...
# 31  [4600, 4691): 'As a result, the man from Scene...
# 32  [4693, 4848): 'When Arthur and Bedevere reach ...
# 33  [4849, 4985): 'Arthur and Bedevere eventually ...
# 34  [4986, 5107): 'After being driven to retreat b...
# 35  [5108, 5274): 'Just as they are charging in to...
# 36  [5275, 5335): 'The movie ends with one of the ...

# %%
import pandas as pd
s = pd.DataFrame(u)
s
# Out:
#                                                     0
# 0   [0, 273): 'Monty Python and the Holy Grail is ...
# 1   [274, 405): 'It was conceived during the hiatu...
# 2   [407, 642): 'While the group's first film, And...
# 3   [643, 720): 'Thirty years later, Idle used the...
# 4   [722, 823): 'Monty Python and the Holy Grail g...
# 5   [824, 954): 'In the US, it was selected as the...
# 6   [955, 1122): 'In the UK, readers of Total Film...
# 7   [1122, 1256): '[5] In AD 932, King Arthur and ...
# 8   [1257, 1488): 'Along the way, he recruits Sir ...
# 9   [1489, 1639): 'Arthur leads the men to Camelot...
# 10  [1640, 1756): 'As they turn away, God (an imag...
# 11  [1758, 1935): 'Searching the land for clues to...
# 12  [1936, 2199): 'After being driven back by a sh...
# 13  [2200, 2309): 'Arthur decides that the knights...
# 14  [2310, 2476): 'A modern-day historian filming ...
# 15  [2478, 2649): 'On the knights' travels, Arthur...
# 16                                 [2649, 2651): '".'
# 17  [2652, 2748): 'Sir Robin avoids a fight with a...
# 18  [2749, 2893): 'Sir Galahad is led by a grail-s...
# 19  [2894, 3196): 'Lancelot, after receiving an ar...
# 20  [3198, 3316): 'Arthur and his knights regroup,...
# 21  [3317, 3427): 'They meet Tim the Enchanter, wh...
# 22  [3428, 3492): 'The entrance to the cave is gua...
# 23  [3493, 3615): 'Fatally underestimating its let...
# 24  [3616, 3717): 'Arthur uses the "Holy Hand Gren...
# 25  [3718, 3905): 'Inside the cave, they find an i...
# 26  [3907, 4094): 'After barely escaping a giant a...
# 27  [4095, 4252): 'As they approach the Bridge of ...
# 28  [4253, 4330): 'Lancelot goes first, easily ans...
# 29  [4331, 4469): 'Robin is surprised by an unexpe...
# 30  [4470, 4599): 'During Arthur's turn, he respon...
# 31  [4600, 4691): 'As a result, the man from Scene...
# 32  [4693, 4848): 'When Arthur and Bedevere reach ...
# 33  [4849, 4985): 'Arthur and Bedevere eventually ...
# 34  [4986, 5107): 'After being driven to retreat b...
# 35  [5108, 5274): 'Just as they are charging in to...
# 36  [5275, 5335): 'The movie ends with one of the ...

# %%
syntax_analysis = response['syntax']['sentences']

# %%
syntax_analysis
# Out:
# [{'text': 'Monty Python and the Holy Grail is a 1975 British comedy film concerning the Arthurian legend, written and performed by the Monty Python comedy group of Graham Chapman, John Cleese, Terry Gilliam, Eric Idle, Terry Jones and Michael Palin, and directed by Gilliam and Jones.',
#   'location': [0, 273]},
#  {'text': "It was conceived during the hiatus between the third and fourth series of their BBC television series Monty Python's Flying Circus.",
#   'location': [274, 405]},
#  {'text': "While the group's first film, And Now for Something Completely Different, was a compilation of sketches from the first two television series, Holy Grail is a new story that parodies the legend of King Arthur's quest for the Holy Grail.",
#   'location': [407, 642]},
#  {'text': 'Thirty years later, Idle used the film as the basis for the musical Spamalot.',
#   'location': [643, 720]},
#  {'text': 'Monty Python and the Holy Grail grossed more than any other British film exhibited in the US in 2005.',
#   'location': [722, 823]},
#  {'text': 'In the US, it was selected as the second-best comedy of all time in the ABC special Best in Film: The Greatest Movies of Our Time.',
#   'location': [824, 954]},
#  {'text': 'In the UK, readers of Total Film magazine in 2000 ranked it the fifth-greatest comedy film of all time;[4] a similar poll of Channel 4 viewers in 2006 placed it sixth.',
#   'location': [955, 1122]},
#  {'text': '[5]  In AD 932, King Arthur and his squire, Patsy, travel throughout Britain searching for men to join the Knights of the Round Table.',
#   'location': [1122, 1256]},
#  {'text': "Along the way, he recruits Sir Bedevere the Wise, Sir Lancelot the Brave, Sir Galahad the Pure, Sir Robin the Not-Quite-So-Brave-as-Sir-Lancelot, and Sir Not-Appearing-in-this-Film, along with their squires and Robin's troubadours.",
#   'location': [1257, 1488]},
#  {'text': 'Arthur leads the men to Camelot, but upon further consideration (thanks to a musical number) he decides not to go there because it is "a silly place".',
#   'location': [1489, 1639]},
#  {'text': 'As they turn away, God (an image of W. G. Grace) speaks to them and gives Arthur the task of finding the Holy Grail.',
#   'location': [1640, 1756]},
#  {'text': "Searching the land for clues to the Grail's location, Arthur and his men come to a castle occupied by rude French soldiers who claim to have the Grail and insult the Englishmen.",
#   'location': [1758, 1935]},
#  {'text': 'After being driven back by a shower of catapulted barnyard animals, Bedevere comes up with a plan to sneak in using a Trojan Rabbit, but they mishandle its execution when they forget to hide inside it, and are forced to flee when the Rabbit is flung back at them.',
#   'location': [1936, 2199]},
#  {'text': "Arthur decides that the knights should go their separate ways to search for clues to the Grail's whereabouts.",
#   'location': [2200, 2309]},
#  {'text': 'A modern-day historian filming a documentary describing the Arthurian legends is abruptly killed by an unknown knight on horseback, triggering a police investigation.',
#   'location': [2310, 2476]},
#  {'text': 'On the knights\' travels, Arthur and Bedevere are given directions by an old man in Scene 24 and attempt to satisfy the strange requests of the dreaded Knights Who Say "Ni!',
#   'location': [2478, 2649]},
#  {'text': '".', 'location': [2649, 2651]},
#  {'text': 'Sir Robin avoids a fight with a Three-Headed Knight by running away while the heads are arguing.',
#   'location': [2652, 2748]},
#  {'text': 'Sir Galahad is led by a grail-shaped beacon to Castle Anthrax, populated by 160 nubile young women, but to his chagrin is "rescued" by Lancelot.',
#   'location': [2749, 2893]},
#  {'text': 'Lancelot, after receiving an arrow-shot note from Swamp Castle believed to be from a lady being forced to marry against her will, rushes to the castle and slaughters nearly the entire wedding party, only to discover that the note was sent by an effeminate prince whose father had arranged the marriage.',
#   'location': [2894, 3196]},
#  {'text': 'Arthur and his knights regroup, and are joined by three new knights, as well as Brother Maynard and his monk brethren.',
#   'location': [3198, 3316]},
#  {'text': 'They meet Tim the Enchanter, who directs them to a cave where the location of the Grail is said to be written.',
#   'location': [3317, 3427]},
#  {'text': 'The entrance to the cave is guarded by the Rabbit of Caerbannog.',
#   'location': [3428, 3492]},
#  {'text': 'Fatally underestimating its lethal prowess, the knights attack the Rabbit, which easily kills Sirs Bors, Gawain and Ector.',
#   'location': [3493, 3615]},
#  {'text': 'Arthur uses the "Holy Hand Grenade of Antioch", provided by Brother Maynard, to destroy the creature.',
#   'location': [3616, 3717]},
#  {'text': 'Inside the cave, they find an inscription from Joseph of Arimathea, directing them to the Castle of Aarrgh (the name presumably the result of Joseph dying whilst carving the inscription).',
#   'location': [3718, 3905]},
#  {'text': "After barely escaping a giant animated monster that devours Brother Maynard (the animator has a heart attack, which ends the beast's existence), they arrive at the Gorge of Eternal Peril.",
#   'location': [3907, 4094]},
#  {'text': 'As they approach the Bridge of Death, the man from Scene 24 challenges them to correctly answer three questions in order to pass - or be cast into the Gorge.',
#   'location': [4095, 4252]},
#  {'text': 'Lancelot goes first, easily answers three simple questions, and crosses over.',
#   'location': [4253, 4330]},
#  {'text': 'Robin is surprised by an unexpectedly difficult question, and Galahad misses the answer to an easy one, and both are flung off the bridge.',
#   'location': [4331, 4469]},
#  {'text': "During Arthur's turn, he responds to the bridge-keeper's last question with a question of his own which stumps the bridge-keeper.",
#   'location': [4470, 4599]},
#  {'text': 'As a result, the man from Scene 24 is thrown into the gorge, and Arthur and Bedevere cross.',
#   'location': [4600, 4691]},
#  {'text': "When Arthur and Bedevere reach the bridge's end, they cannot find Lancelot, unaware he has been arrested by the police investigating the historian's death.",
#   'location': [4693, 4848]},
#  {'text': 'Arthur and Bedevere eventually reach the Castle of Aarrgh, only to find it occupied by the same French soldiers who taunted them before.',
#   'location': [4849, 4985]},
#  {'text': 'After being driven to retreat by showers of manure, they amass a large army of knights and prepare to assault the castle.',
#   'location': [4986, 5107]},
#  {'text': "Just as they are charging in to attack, a large force of police shows up, arrests Arthur and Bedevere for the historian's death, and shuts down the film's production.",
#   'location': [5108, 5274]},
#  {'text': 'The movie ends with one of the officers breaking the camera.',
#   'location': [5275, 5335]}]

# %%
# TODO - tokens come in a different dictionary than sentences

# Find all the pronouns in each sentence, *without* using Pandas.

# Version 1: Chain together accessor methods of the Python class that wraps 
# syntax analysis results.

'''syntax_analysis = response['syntax']['sentences']
token_spans_by_sentence = {
    s: l
    for s, l in zip(syntax_analysis.text, 
                    syntax_analysis.location)
}
pronouns_by_sentence = {}
for sentence, offsets_list in token_spans_by_sentence.items():
    pronouns_in_sentence = []
    for offsets_tuple in offsets_list:
        token_ix = syntax_analysis.find_token(offsets_tuple[0])
        if token_ix < 0:
            raise ValueError(f"No token found at offset {offsets_tuple[0]}")
        token = syntax_analysis.tokens[token_ix]
        pos_str = token.to_dict()["part_of_speech"]  # Decode numeric POS enum
        if pos_str == "POS_PRON":
            pronouns_in_sentence.append(token)
    pronouns_by_sentence[sentence] = pronouns_in_sentence

pronouns_by_sentence
'''
# Out:
# 'syntax_analysis = response[\'syntax\'][\'sentences\']\ntoken_spans_by_sentence = {\n    s: l\n    for s, l in zip(syntax_analysis.text, \n                    syntax_analysis.location)\n}\npronouns_by_sentence = {}\nfor sentence, offsets_list in token_spans_by_sentence.items():\n    pronouns_in_sentence = []\n    for offsets_tuple in offsets_list:\n        token_ix = syntax_analysis.find_token(offsets_tuple[0])\n        if token_ix < 0:\n            raise ValueError(f"No token found at offset {offsets_tuple[0]}")\n        token = syntax_analysis.tokens[token_ix]\n        pos_str = token.to_dict()["part_of_speech"]  # Decode numeric POS enum\n        if pos_str == "POS_PRON":\n            pronouns_in_sentence.append(token)\n    pronouns_by_sentence[sentence] = pronouns_in_sentence\n\npronouns_by_sentence\n'

# %%
# Find all the pronouns in each sentence.
# Pandas version.
pronouns_by_sentence = df[df["part_of_speech"] == "PRON"][["sentence", "token_span"]]
pronouns_by_sentence
# Out:
#                                                sentence  \
# 52    [274, 405): 'It was conceived during the hiatu...
# 65    [274, 405): 'It was conceived during the hiatu...
# 85    [407, 642): 'While the group's first film, And...
# 107   [407, 642): 'While the group's first film, And...
# 161   [824, 954): 'In the US, it was selected as the...
# 185   [824, 954): 'In the US, it was selected as the...
# 200   [955, 1122): 'In the UK, readers of Total Film...
# 224   [955, 1122): 'In the UK, readers of Total Film...
# 237   [1122, 1256): '[5] In AD 932, King Arthur and ...
# 261   [1257, 1488): 'Along the way, he recruits Sir ...
# 303   [1257, 1488): 'Along the way, he recruits Sir ...
# 309   [1257, 1488): 'Along the way, he recruits Sir ...
# 334   [1489, 1639): 'Arthur leads the men to Camelot...
# 341   [1489, 1639): 'Arthur leads the men to Camelot...
# 350   [1640, 1756): 'As they turn away, God (an imag...
# 365   [1640, 1756): 'As they turn away, God (an imag...
# 390   [1758, 1935): 'Searching the land for clues to...
# 401   [1758, 1935): 'Searching the land for clues to...
# 439   [1936, 2199): 'After being driven back by a sh...
# 441   [1936, 2199): 'After being driven back by a sh...
# 444   [1936, 2199): 'After being driven back by a sh...
# 449   [1936, 2199): 'After being driven back by a sh...
# 463   [1936, 2199): 'After being driven back by a sh...
# 472   [2200, 2309): 'Arthur decides that the knights...
# 542   [2478, 2649): 'On the knights' travels, Arthur...
# 592   [2749, 2893): 'Sir Galahad is led by a grail-s...
# 624   [2894, 3196): 'Lancelot, after receiving an ar...
# 660   [3198, 3316): 'Arthur and his knights regroup,...
# 678   [3198, 3316): 'Arthur and his knights regroup,...
# 682   [3317, 3427): 'They meet Tim the Enchanter, wh...
# 688   [3317, 3427): 'They meet Tim the Enchanter, wh...
# 690   [3317, 3427): 'They meet Tim the Enchanter, wh...
# 721   [3493, 3615): 'Fatally underestimating its let...
# 731   [3493, 3615): 'Fatally underestimating its let...
# 766   [3718, 3905): 'Inside the cave, they find an i...
# 776   [3718, 3905): 'Inside the cave, they find an i...
# 804   [3907, 4094): 'After barely escaping a giant a...
# 816   [3907, 4094): 'After barely escaping a giant a...
# 824   [3907, 4094): 'After barely escaping a giant a...
# 834   [4095, 4252): 'As they approach the Bridge of ...
# 847   [4095, 4252): 'As they approach the Bridge of ...
# 911   [4470, 4599): 'During Arthur's turn, he respon...
# 925   [4470, 4599): 'During Arthur's turn, he respon...
# 927   [4470, 4599): 'During Arthur's turn, he respon...
# 965   [4693, 4848): 'When Arthur and Bedevere reach ...
# 972   [4693, 4848): 'When Arthur and Bedevere reach ...
# 998   [4849, 4985): 'Arthur and Bedevere eventually ...
# 1005  [4849, 4985): 'Arthur and Bedevere eventually ...
# 1007  [4849, 4985): 'Arthur and Bedevere eventually ...
# 1020  [4986, 5107): 'After being driven to retreat b...
# 1036  [5108, 5274): 'Just as they are charging in to...
#
#                    token_span
# 52           [274, 276): 'It'
# 65        [348, 353): 'their'
# 85    [449, 458): 'Something'
# 107        [575, 579): 'that'
# 161          [835, 837): 'it'
# 185         [945, 948): 'Our'
# 200        [1012, 1014): 'it'
# 224        [1113, 1115): 'it'
# 237       [1154, 1157): 'his'
# 261        [1272, 1274): 'he'
# 303      [1428, 1432): 'this'
# 309     [1450, 1455): 'their'
# 334        [1582, 1584): 'he'
# 341        [1617, 1619): 'it'
# 350      [1643, 1647): 'they'
# 365      [1699, 1703): 'them'
# 390       [1823, 1826): 'his'
# 401       [1881, 1884): 'who'
# 439      [2073, 2077): 'they'
# 441       [2088, 2091): 'its'
# 444      [2107, 2111): 'they'
# 449        [2134, 2136): 'it'
# 463      [2194, 2198): 'them'
# 472     [2242, 2247): 'their'
# 542       [2637, 2640): 'Who'
# 592       [2856, 2859): 'his'
# 624       [3014, 3017): 'her'
# 660       [3209, 3212): 'his'
# 678       [3298, 3301): 'his'
# 682      [3317, 3321): 'They'
# 688       [3346, 3349): 'who'
# 690      [3358, 3362): 'them'
# 721       [3517, 3520): 'its'
# 731     [3568, 3573): 'which'
# 766      [3735, 3739): 'they'
# 776      [3796, 3800): 'them'
# 804      [3954, 3958): 'that'
# 816     [4017, 4022): 'which'
# 824      [4052, 4056): 'they'
# 834      [4098, 4102): 'they'
# 847      [4166, 4170): 'them'
# 911        [4492, 4494): 'he'
# 925       [4560, 4563): 'his'
# 927     [4568, 4573): 'which'
# 965      [4742, 4746): 'they'
# 972        [4777, 4779): 'he'
# 998        [4921, 4923): 'it'
# 1005      [4961, 4964): 'who'
# 1007     [4973, 4977): 'them'
# 1020     [5038, 5042): 'they'
# 1036     [5116, 5120): 'they'

# %%
# How would the previous cell look if the tokens and sentences weren't pre-joined?
pronouns = df[df["part_of_speech"] == "PRON"]["token_span"]
pronouns_by_sentence = tp.contain_join(sentences["sentence"], pronouns, "sentence", "token_span")
pronouns_by_sentence
# Out:
#                                              sentence               token_span
# 0   [274, 405): 'It was conceived during the hiatu...         [274, 276): 'It'
# 1   [274, 405): 'It was conceived during the hiatu...      [348, 353): 'their'
# 2   [407, 642): 'While the group's first film, And...  [449, 458): 'Something'
# 3   [407, 642): 'While the group's first film, And...       [575, 579): 'that'
# 4   [824, 954): 'In the US, it was selected as the...         [835, 837): 'it'
# 5   [824, 954): 'In the US, it was selected as the...        [945, 948): 'Our'
# 6   [955, 1122): 'In the UK, readers of Total Film...       [1012, 1014): 'it'
# 7   [955, 1122): 'In the UK, readers of Total Film...       [1113, 1115): 'it'
# 8   [1122, 1256): '[5] In AD 932, King Arthur and ...      [1154, 1157): 'his'
# 9   [1257, 1488): 'Along the way, he recruits Sir ...       [1272, 1274): 'he'
# 10  [1257, 1488): 'Along the way, he recruits Sir ...     [1428, 1432): 'this'
# 11  [1257, 1488): 'Along the way, he recruits Sir ...    [1450, 1455): 'their'
# 12  [1489, 1639): 'Arthur leads the men to Camelot...       [1582, 1584): 'he'
# 13  [1489, 1639): 'Arthur leads the men to Camelot...       [1617, 1619): 'it'
# 14  [1640, 1756): 'As they turn away, God (an imag...     [1643, 1647): 'they'
# 15  [1640, 1756): 'As they turn away, God (an imag...     [1699, 1703): 'them'
# 16  [1758, 1935): 'Searching the land for clues to...      [1823, 1826): 'his'
# 17  [1758, 1935): 'Searching the land for clues to...      [1881, 1884): 'who'
# 18  [1936, 2199): 'After being driven back by a sh...     [2073, 2077): 'they'
# 19  [1936, 2199): 'After being driven back by a sh...      [2088, 2091): 'its'
# 20  [1936, 2199): 'After being driven back by a sh...     [2107, 2111): 'they'
# 21  [1936, 2199): 'After being driven back by a sh...       [2134, 2136): 'it'
# 22  [1936, 2199): 'After being driven back by a sh...     [2194, 2198): 'them'
# 23  [2200, 2309): 'Arthur decides that the knights...    [2242, 2247): 'their'
# 24  [2478, 2649): 'On the knights' travels, Arthur...      [2637, 2640): 'Who'
# 25  [2749, 2893): 'Sir Galahad is led by a grail-s...      [2856, 2859): 'his'
# 26  [2894, 3196): 'Lancelot, after receiving an ar...      [3014, 3017): 'her'
# 27  [3198, 3316): 'Arthur and his knights regroup,...      [3209, 3212): 'his'
# 28  [3198, 3316): 'Arthur and his knights regroup,...      [3298, 3301): 'his'
# 29  [3317, 3427): 'They meet Tim the Enchanter, wh...     [3317, 3321): 'They'
# 30  [3317, 3427): 'They meet Tim the Enchanter, wh...      [3346, 3349): 'who'
# 31  [3317, 3427): 'They meet Tim the Enchanter, wh...     [3358, 3362): 'them'
# 32  [3493, 3615): 'Fatally underestimating its let...      [3517, 3520): 'its'
# 33  [3493, 3615): 'Fatally underestimating its let...    [3568, 3573): 'which'
# 34  [3718, 3905): 'Inside the cave, they find an i...     [3735, 3739): 'they'
# 35  [3718, 3905): 'Inside the cave, they find an i...     [3796, 3800): 'them'
# 36  [3907, 4094): 'After barely escaping a giant a...     [3954, 3958): 'that'
# 37  [3907, 4094): 'After barely escaping a giant a...    [4017, 4022): 'which'
# 38  [3907, 4094): 'After barely escaping a giant a...     [4052, 4056): 'they'
# 39  [4095, 4252): 'As they approach the Bridge of ...     [4098, 4102): 'they'
# 40  [4095, 4252): 'As they approach the Bridge of ...     [4166, 4170): 'them'
# 41  [4470, 4599): 'During Arthur's turn, he respon...       [4492, 4494): 'he'
# 42  [4470, 4599): 'During Arthur's turn, he respon...      [4560, 4563): 'his'
# 43  [4470, 4599): 'During Arthur's turn, he respon...    [4568, 4573): 'which'
# 44  [4693, 4848): 'When Arthur and Bedevere reach ...     [4742, 4746): 'they'
# 45  [4693, 4848): 'When Arthur and Bedevere reach ...       [4777, 4779): 'he'
# 46  [4849, 4985): 'Arthur and Bedevere eventually ...       [4921, 4923): 'it'
# 47  [4849, 4985): 'Arthur and Bedevere eventually ...      [4961, 4964): 'who'
# 48  [4849, 4985): 'Arthur and Bedevere eventually ...     [4973, 4977): 'them'
# 49  [4986, 5107): 'After being driven to retreat b...     [5038, 5042): 'they'
# 50  [5108, 5274): 'Just as they are charging in to...     [5116, 5120): 'they'

# %%
# Ask the tokens of the first sentence to render themselves as HTML
sentence_tokens_df = df[df["sentence"] == sentences["sentence"].loc[0]]
sentence_tokens_df["char_span"].values
# Out:
# <CharSpanArray>
# [        [0, 5): 'Monty',       [6, 12): 'Python',         [13, 16): 'and',
#          [17, 20): 'the',        [21, 25): 'Holy',       [26, 31): 'Grail',
#           [32, 34): 'is',           [35, 36): 'a',        [37, 41): '1975',
#      [42, 49): 'British',      [50, 56): 'comedy',        [57, 61): 'film',
#   [62, 72): 'concerning',         [73, 76): 'the',   [77, 86): 'Arthurian',
#       [87, 93): 'legend',           [93, 94): ',',    [95, 102): 'written',
#        [103, 106): 'and', [107, 116): 'performed',        [117, 119): 'by',
#        [120, 123): 'the',     [124, 129): 'Monty',    [130, 136): 'Python',
#     [137, 143): 'comedy',     [144, 149): 'group',        [150, 152): 'of',
#     [153, 159): 'Graham',   [160, 167): 'Chapman',         [167, 168): ',',
#       [169, 173): 'John',    [174, 180): 'Cleese',         [180, 181): ',',
#      [182, 187): 'Terry',   [188, 195): 'Gilliam',         [195, 196): ',',
#       [197, 201): 'Eric',      [202, 206): 'Idle',         [206, 207): ',',
#      [208, 213): 'Terry',     [214, 219): 'Jones',       [220, 223): 'and',
#    [224, 231): 'Michael',     [232, 237): 'Palin',         [237, 238): ',',
#        [239, 242): 'and',  [243, 251): 'directed',        [252, 254): 'by',
#    [255, 262): 'Gilliam',       [263, 266): 'and',     [267, 272): 'Jones',
#          [272, 273): '.']
# Length: 52, dtype: CharSpanType

# %%
# Display our the first sentence's dependency parse
sentence_tokens_df = df[df["sentence"] == sentences["sentence"].loc[0]]
tp.render_parse_tree(sentence_tokens_df, tag_col=None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-48-dab7b9352f8d> in <module>
#       1 # Display our the first sentence's dependency parse
#       2 sentence_tokens_df = df[df["sentence"] == sentences["sentence"].loc[0]]
# ----> 3 tp.render_parse_tree(sentence_tokens_df, tag_col=None)
#
# ~/git/stc/text-extensions-for-pandas/text_extensions_for_pandas/io/spacy.py in render_parse_tree(token_features, text_col, tag_col, label_col)
#     245     See https://spacy.io/usage/visualizers for the specification of this format.
#     246     """
# --> 247     import spacy.displacy
#     248
#     249     return spacy.displacy.render(
#
# ModuleNotFoundError: No module named 'spacy'
