# %% [markdown]
# ## Watson NLP Example for Text Extensions for Pandas
#
# This demo shows how to use the `watson` module from Text Extension for Pandas to
# process a Watson NLP response from the IBM cloud into Pandas DataFrames for analysis.
# The responses should be in the form of decoded JSON Python and the following features
# will be processed into DataFrames:
#
# * entities
# * keywords
# * relations
# * semantic_roles
# * syntax with sentences and tokens
#
# To properly authenticate with IBM Cloud, please set the environment variable
# `IBM_AUTH_KEY` with your correct apikey to make requests to
# `ibm_watson.NaturalLanguageUnderstandingV1`.

# %%
# INITIALIZATION BOILERPLATE

# The Jupyter kernel for this notebook usually starts up inside the notebooks
# directory, but the text_extensions_for_pandas package code is in the parent
# directory. Add that parent directory to the front of the Python include path.
import sys
if (sys.path[0] != ".."):
    sys.path[0] = ".."

import json
import os
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, CategoriesOptions, ConceptsOptions, EmotionOptions, EntitiesOptions, KeywordsOptions, \
    MetadataOptions, RelationsOptions, SemanticRolesOptions, SentimentOptions, SyntaxOptions, SyntaxOptionsTokens
from text_extensions_for_pandas.io.watson import watson_nlu_parse_response

# %%
# Retrieve the APIKEY for authentication
apikey = os.environ.get("IBM_AUTH_KEY")
if apikey is None:
    raise ValueError("Expected apikey in the environment variable 'IBM_AUTH_KEY'")

# %%
# Initialize the authenticator for making requests
authenticator = IAMAuthenticator(apikey)
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.us-south.natural-language-understanding.watson.cloud.ibm.com/instances/21b9b875-4ddb-46ad-bb22-d78747622ca7')

# %%
# Make the request
response = natural_language_understanding.analyze(
    url='https://raw.githubusercontent.com/CODAIT/text-extensions-for-pandas/master/resources/holy_grail.txt',
    features=Features(
        #categories=CategoriesOptions(limit=3), 
        #concepts=ConceptsOptions(limit=3), 
        #emotion=EmotionOptions(targets=['grail']),
        entities=EntitiesOptions(sentiment=True,limit=3),
        keywords=KeywordsOptions(sentiment=True,emotion=True,limit=3),
        #metadata=MetadataOptions(),
        relations=RelationsOptions(),
        semantic_roles=SemanticRolesOptions(limit=3),
        #sentiment=SentimentOptions(targets=['Arthur']),
        syntax=SyntaxOptions(sentences=True, tokens=SyntaxOptionsTokens(lemma=True, part_of_speech=True))  # Experimental
    )).get_result()

# %%
# View response as JSON
#json.dumps(response, indent=2)
response

# %%
# Get the response as processed Pandas DataFrames
dfs = watson_nlu_parse_response(response)

# %%
# Created DataFrames from the response
dfs.keys()
# Out:
# dict_keys(['entities', 'keywords', 'relations', 'semantic_roles', 'syntax'])

# %%
dfs['keywords']
# Out:
#    count  emotion.anger  emotion.disgust  emotion.fear  emotion.joy  \
# 0      1       0.071927         0.031335      0.058051     0.691404
# 1      1       0.021033         0.095661      0.016340     0.810654
# 2      1       0.112061         0.033299      0.043658     0.747356
#
#    emotion.sadness  relevance sentiment.label  sentiment.score  \
# 0         0.175057   0.746411         neutral         0.000000
# 1         0.046902   0.642571        positive         0.835873
# 2         0.091490   0.642235         neutral         0.000000
#
#                     text
# 0  legend of King Arthur
# 1           Sir Lancelot
# 2            King Arthur

# %%
dfs['entities']
# Out:
#    confidence  count  relevance sentiment.label sentiment.mixed  \
# 0    1.000000     12   0.956097        negative               1
# 1    1.000000      5   0.678523        positive            None
# 2    0.977538      2   0.644313         neutral            None
#
#    sentiment.score          text    type
# 0        -0.312834        Arthur  Person
# 1         0.835873      Lancelot  Person
# 2         0.000000  Monty Python  Person

# %%
dfs['relations']
# Out:
#    arguments.entities.disambiguation.subtype  \
# 0                           [[None], [None]]
# 1                           [[None], [None]]
# 2                           [[None], [None]]
# 3                           [[None], [None]]
# 4                      [[None], [[Country]]]
# 5                      [[None], [[Country]]]
# 6                           [[None], [None]]
# 7                           [[None], [None]]
# 8                           [[None], [None]]
# 9                           [[None], [None]]
# 10                          [[None], [None]]
# 11                          [[None], [None]]
# 12                          [[None], [None]]
# 13                          [[None], [None]]
# 14                          [[None], [None]]
# 15                          [[None], [None]]
# 16                          [[None], [None]]
# 17                          [[None], [None]]
# 18                          [[None], [None]]
# 19                          [[None], [None]]
# 20                          [[None], [None]]
# 21                          [[None], [None]]
# 22                          [[None], [None]]
# 23                          [[None], [None]]
# 24                          [[None], [None]]
# 25                          [[None], [None]]
# 26                          [[None], [None]]
# 27                          [[None], [None]]
# 28                          [[None], [None]]
# 29                          [[None], [None]]
# 30                    [[None], [[Military]]]
# 31                          [[None], [None]]
# 32                          [[None], [None]]
# 33                          [[None], [None]]
# 34                          [[None], [None]]
# 35                          [[None], [None]]
# 36                          [[None], [None]]
# 37                          [[None], [None]]
# 38                          [[None], [None]]
#
#                             arguments.entities.text  \
# 0                                [[1975], [comedy]]
# 1                                [[men], [Camelot]]
# 2                               [[their], [speaks]]
# 3                             [[Grail], [location]]
# 4                            [[soldiers], [French]]
# 5                            [[soldiers], [French]]
# 6                             [[soldiers], [claim]]
# 7                        [[Grail], [investigation]]
# 8                              [[Robin], [arguing]]
# 9                            [[Lancelot], [castle]]
# 10                         [[King Arthur], [whose]]
# 11                 [[Tim the Enchanter], [knights]]
# 12  [[Monty Python comedy group], [Graham Chapman]]
# 13                    [[Tim the Enchanter], [cave]]
# 14                             [[cave], [location]]
# 15                            [[knights], [attack]]
# 16               [[Rabbit of Caerbannog], [attack]]
# 17   [[Brother Maynard], [Hand Grenade of Antioch]]
# 18                   [[Brother Maynard], [knights]]
# 19              [[Brother Maynard], [heart attack]]
# 20                      [[King Arthur], [responds]]
# 21                        [[King Arthur], [bridge]]
# 22                        [[King Arthur], [bridge]]
# 23                         [[King Arthur], [Scene]]
# 24                          [[Eric Idle], [comedy]]
# 25                             [[Bedevere], [they]]
# 26                       [[King Arthur], [arrests]]
# 27                       [[King Arthur], [arrests]]
# 28                       [[Grail], [investigating]]
# 29                 [[King Arthur], [investigating]]
# 30                              [[knights], [army]]
# 31                            [[castle], [assault]]
# 32                           [[soldiers], [attack]]
# 33    [[The Greatest Movies of Our Time], [comedy]]
# 34                               [[2000], [comedy]]
# 35                             [[Galahad], [their]]
# 36                            [[Lancelot], [their]]
# 37                             [[their], [squires]]
# 38                       [[King Arthur], [Camelot]]
#
#                    arguments.entities.type            arguments.location  \
# 0                    [[Date], [TitleWork]]          [[37, 41], [57, 61]]
# 1         [[Person], [GeopoliticalEntity]]  [[1506, 1509], [1513, 1520]]
# 2         [[Person], [EventCommunication]]  [[1699, 1703], [1689, 1695]]
# 3             [[Organization], [Location]]  [[1794, 1799], [1802, 1810]]
# 4         [[Person], [GeopoliticalEntity]]  [[1872, 1880], [1865, 1871]]
# 5         [[Person], [GeopoliticalEntity]]  [[4952, 4960], [4945, 4951]]
# 6         [[Person], [EventCommunication]]  [[1881, 1884], [1885, 1890]]
# 7           [[Organization], [EventLegal]]  [[2455, 2461], [2462, 2475]]
# 8         [[Person], [EventCommunication]]  [[2656, 2661], [2740, 2747]]
# 9                   [[Person], [Facility]]  [[2894, 2902], [3038, 3044]]
# 10                    [[Person], [Person]]  [[3163, 3169], [3157, 3162]]
# 11                    [[Person], [Person]]  [[3346, 3349], [3358, 3362]]
# 12  [[Organization], [GeopoliticalEntity]]      [[124, 149], [153, 167]]
# 13                  [[Person], [Facility]]  [[3346, 3349], [3368, 3372]]
# 14                [[Facility], [Location]]  [[3373, 3378], [3383, 3391]]
# 15             [[Person], [EventViolence]]  [[3541, 3548], [3549, 3555]]
# 16       [[Organization], [EventViolence]]  [[3560, 3566], [3549, 3555]]
# 17                 [[Person], [TitleWork]]  [[3676, 3691], [3638, 3661]]
# 18                    [[Person], [Person]]  [[3967, 3982], [4052, 4056]]
# 19           [[Person], [HealthCondition]]  [[3988, 3996], [4003, 4015]]
# 20        [[Person], [EventCommunication]]  [[4492, 4494], [4495, 4503]]
# 21                  [[Person], [Facility]]  [[4492, 4494], [4511, 4517]]
# 22                  [[Person], [Facility]]  [[4560, 4563], [4585, 4591]]
# 23                  [[Person], [Location]]  [[4617, 4620], [4626, 4631]]
# 24                 [[Person], [TitleWork]]      [[663, 667], [677, 681]]
# 25                    [[Person], [Person]]  [[4709, 4717], [4742, 4746]]
# 26              [[Person], [EventCustody]]  [[4777, 4779], [4789, 4797]]
# 27              [[Person], [EventCustody]]  [[5190, 5196], [5182, 5189]]
# 28          [[Organization], [EventLegal]]  [[4805, 4811], [4812, 4825]]
# 29                [[Person], [EventLegal]]  [[4830, 4839], [4812, 4825]]
# 30              [[Person], [Organization]]  [[5065, 5072], [5057, 5061]]
# 31           [[Facility], [EventViolence]]  [[5100, 5106], [5088, 5095]]
# 32             [[Person], [EventViolence]]  [[5116, 5120], [5140, 5146]]
# 33              [[TitleWork], [TitleWork]]      [[922, 953], [870, 876]]
# 34                   [[Date], [TitleWork]]  [[1000, 1004], [1041, 1045]]
# 35                    [[Person], [Person]]  [[1335, 1342], [1450, 1455]]
# 36                    [[Person], [Person]]  [[1393, 1401], [1450, 1455]]
# 37                    [[Person], [Person]]  [[1450, 1455], [1456, 1463]]
# 38        [[Person], [GeopoliticalEntity]]  [[1489, 1495], [1513, 1520]]
#
#                                  arguments.text     score  \
# 0                                  [1975, film]  0.462615
# 1                                [men, Camelot]  0.339446
# 2                                [them, speaks]  0.604304
# 3                             [Grail, location]  0.304596
# 4                            [soldiers, French]  0.895035
# 5                            [soldiers, French]  0.903545
# 6                                  [who, claim]  0.945371
# 7                       [police, investigation]  0.943395
# 8                              [Robin, arguing]  0.600505
# 9                            [Lancelot, castle]  0.542254
# 10                              [father, whose]  0.581076
# 11                                  [who, them]  0.474501
# 12  [Monty Python comedy group, Graham Chapman]  0.817482
# 13                                  [who, cave]  0.765512
# 14                            [where, location]  0.565815
# 15                            [knights, attack]  0.947217
# 16                             [Rabbit, attack]  0.587099
# 17   [Brother Maynard, Hand Grenade of Antioch]  0.791427
# 18                      [Brother Maynard, they]  0.692562
# 19                     [animator, heart attack]  0.467027
# 20                               [he, responds]  0.996934
# 21                                 [he, bridge]  0.691983
# 22                                [his, bridge]  0.603077
# 23                                 [man, Scene]  0.506421
# 24                                 [Idle, film]  0.852951
# 25                             [Bedevere, they]  0.781408
# 26                               [he, arrested]  0.922504
# 27                            [Arthur, arrests]  0.636730
# 28                      [police, investigating]  0.876697
# 29                   [historian, investigating]  0.591005
# 30                              [knights, army]  0.582838
# 31                            [castle, assault]  0.805495
# 32                               [they, attack]  0.616224
# 33    [The Greatest Movies of Our Time, comedy]  0.414410
# 34                                 [2000, film]  0.508347
# 35                             [Galahad, their]  0.610221
# 36                            [Lancelot, their]  0.710112
# 37                             [their, squires]  0.382100
# 38                            [Arthur, Camelot]  0.492869
#
#                                              sentence          type
# 0   Monty Python and the Holy Grail is a 1975 Brit...        timeOf
# 1   Arthur leads the men to Camelot, but upon furt...     locatedAt
# 2   As they turn away, God (an image of W. G. Grac...    affectedBy
# 3   Searching the land for clues to the Grail's lo...     locatedAt
# 4   Searching the land for clues to the Grail's lo...    employedBy
# 5   Arthur and Bedevere eventually reach the Castl...    employedBy
# 6   Searching the land for clues to the Grail's lo...       agentOf
# 7   A modern-day historian filming a documentary d...       agentOf
# 8   Sir Robin avoids a fight with a Three-Headed K...       agentOf
# 9   Lancelot, after receiving an arrow-shot note f...     locatedAt
# 10  Lancelot, after receiving an arrow-shot note f...      parentOf
# 11  They meet Tim the Enchanter, who directs them ...    partOfMany
# 12  Monty Python and the Holy Grail is a 1975 Brit...       basedIn
# 13  They meet Tim the Enchanter, who directs them ...     locatedAt
# 14  They meet Tim the Enchanter, who directs them ...     locatedAt
# 15  Fatally underestimating its lethal prowess, th...       agentOf
# 16  Fatally underestimating its lethal prowess, th...    affectedBy
# 17  Arthur uses the "Holy Hand Grenade of Antioch"...      authorOf
# 18  After barely escaping a giant animated monster...    partOfMany
# 19  After barely escaping a giant animated monster...  hasAttribute
# 20  During Arthur's turn, he responds to the bridg...       agentOf
# 21  During Arthur's turn, he responds to the bridg...     locatedAt
# 22  During Arthur's turn, he responds to the bridg...     locatedAt
# 23  As a result, the man from Scene 24 is thrown i...     locatedAt
# 24  Thirty years later, Idle used the film as the ...      authorOf
# 25  When Arthur and Bedevere reach the bridge's en...    partOfMany
# 26  When Arthur and Bedevere reach the bridge's en...    affectedBy
# 27  Just as they are charging in to attack, a larg...    affectedBy
# 28  When Arthur and Bedevere reach the bridge's en...       agentOf
# 29  When Arthur and Bedevere reach the bridge's en...    affectedBy
# 30  After being driven to retreat by showers of ma...    employedBy
# 31  After being driven to retreat by showers of ma...    affectedBy
# 32  Just as they are charging in to attack, a larg...       agentOf
# 33  In the US, it was selected as the second-best ...    partOfMany
# 34  In the UK, readers of Total Film magazine in 2...        timeOf
# 35  Along the way, he recruits Sir Bedevere the Wi...    partOfMany
# 36  Along the way, he recruits Sir Bedevere the Wi...    partOfMany
# 37  Along the way, he recruits Sir Bedevere the Wi...      parentOf
# 38  Arthur leads the men to Camelot, but upon furt...     residesIn

# %%
dfs['syntax']
# Out:
#         lemma      location part_of_speech      text  \
# 0        None        [0, 5]          PROPN     Monty
# 1      python       [6, 12]          PROPN    Python
# 2         and      [13, 16]          CCONJ       and
# 3         the      [17, 20]            DET       the
# 4        None      [21, 25]          PROPN      Holy
# ...       ...           ...            ...       ...
# 1076  officer  [5306, 5314]           NOUN  officers
# 1077    break  [5315, 5323]           VERB  breaking
# 1078      the  [5324, 5327]            DET       the
# 1079   camera  [5328, 5334]           NOUN    camera
# 1080     None  [5334, 5335]          PUNCT         .
#
#                      char_span                token_span  \
# 0              [0, 5): 'Monty'           [0, 5): 'Monty'
# 1            [6, 12): 'Python'         [6, 12): 'Python'
# 2              [13, 16): 'and'           [13, 16): 'and'
# 3              [17, 20): 'the'           [17, 20): 'the'
# 4             [21, 25): 'Holy'          [21, 25): 'Holy'
# ...                        ...                       ...
# 1076  [5306, 5314): 'officers'  [5306, 5314): 'officers'
# 1077  [5315, 5323): 'breaking'  [5315, 5323): 'breaking'
# 1078       [5324, 5327): 'the'       [5324, 5327): 'the'
# 1079    [5328, 5334): 'camera'    [5328, 5334): 'camera'
# 1080         [5334, 5335): '.'         [5334, 5335): '.'
#
#                                                sentence
# 0     [0, 273): 'Monty Python and the Holy Grail is ...
# 1     [0, 273): 'Monty Python and the Holy Grail is ...
# 2     [0, 273): 'Monty Python and the Holy Grail is ...
# 3     [0, 273): 'Monty Python and the Holy Grail is ...
# 4     [0, 273): 'Monty Python and the Holy Grail is ...
# ...                                                 ...
# 1076  [5275, 5335): 'The movie ends with one of the ...
# 1077  [5275, 5335): 'The movie ends with one of the ...
# 1078  [5275, 5335): 'The movie ends with one of the ...
# 1079  [5275, 5335): 'The movie ends with one of the ...
# 1080  [5275, 5335): 'The movie ends with one of the ...
#
# [1081 rows x 7 columns]
